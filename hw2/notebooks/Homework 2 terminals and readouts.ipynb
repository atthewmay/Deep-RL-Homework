# %% [markdown]
# # Plotting the CartPole experiment results

# %% [markdown]
# Experiements follow
# Note that some were run in the terminal and thus do not show up here.
#
# Everything was run exactly as /n
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 1000 -e 3 -dna --exp_name sb_no_rtg_dna
#
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 1000 -e 3 -rtg -dna --exp_name sb_rtg_dna
#
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 1000 -e 3 -rtg --exp_name sb_rtg_na
#
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -dna --exp_name lb_no_rtg_dna
#
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -rtg -dna --exp_name lb_rtg_dna
#
#
# python train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -rtg --exp_name lb_rtg_na

# %%
! python ../train_pg_f18.py CartPole-v0 -n 100 -b 1000 -e 3 -rtg --exp_name sb_rtg_na
# Out:
# Running experiment with seed 1
# Logging data to data/sb_rtg_na_CartPole-v0_10-09-2019_17-38-51/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is 0.00848375
# ----------------------------------------
# |               Time |            3.15 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            11.1 |
# |          MaxReturn |              56 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            11.1 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        1.02e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is 0.00979037
# ----------------------------------------
# |               Time |            3.59 |
# |          Iteration |               1 |
# |      AverageReturn |            23.7 |
# |          StdReturn |            10.8 |
# |          MaxReturn |              54 |
# |          MinReturn |              10 |
# |          EpLenMean |            23.7 |
# |           EpLenStd |            10.8 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        2.04e+03 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is 0.00748078
# ----------------------------------------
# |               Time |            4.06 |
# |          Iteration |               2 |
# |      AverageReturn |            31.9 |
# |          StdReturn |            17.9 |
# |          MaxReturn |              92 |
# |          MinReturn |              12 |
# |          EpLenMean |            31.9 |
# |           EpLenStd |            17.9 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        3.06e+03 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is 0.0139534
# ----------------------------------------
# |               Time |            4.53 |
# |          Iteration |               3 |
# |      AverageReturn |            35.1 |
# |          StdReturn |            19.5 |
# |          MaxReturn |              77 |
# |          MinReturn |              12 |
# |          EpLenMean |            35.1 |
# |           EpLenStd |            19.5 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        4.08e+03 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is 0.0198138
# ----------------------------------------
# |               Time |            4.94 |
# |          Iteration |               4 |
# |      AverageReturn |            37.1 |
# |          StdReturn |            17.5 |
# |          MaxReturn |              81 |
# |          MinReturn |              19 |
# |          EpLenMean |            37.1 |
# |           EpLenStd |            17.5 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        5.08e+03 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is 0.0100713
# ----------------------------------------
# |               Time |            5.35 |
# |          Iteration |               5 |
# |      AverageReturn |              39 |
# |          StdReturn |            15.3 |
# |          MaxReturn |              70 |
# |          MinReturn |              14 |
# |          EpLenMean |              39 |
# |           EpLenStd |            15.3 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |         6.1e+03 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is 0.00360922
# ----------------------------------------
# |               Time |            5.85 |
# |          Iteration |               6 |
# |      AverageReturn |            49.8 |
# |          StdReturn |            28.1 |
# |          MaxReturn |             136 |
# |          MinReturn |              19 |
# |          EpLenMean |            49.8 |
# |           EpLenStd |            28.1 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        7.19e+03 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is 0.00947313
# ----------------------------------------
# |               Time |            6.28 |
# |          Iteration |               7 |
# |      AverageReturn |            41.9 |
# |          StdReturn |            20.5 |
# |          MaxReturn |              95 |
# |          MinReturn |              17 |
# |          EpLenMean |            41.9 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        1.00e+03 |
# |     TimestepsSoFar |         8.2e+03 |
# ----------------------------------------
# ********** Iteration 8 ************
# the loss is 0.0116609
# ----------------------------------------
# |               Time |            6.77 |
# |          Iteration |               8 |
# |      AverageReturn |            50.9 |
# |          StdReturn |            30.5 |
# |          MaxReturn |             127 |
# |          MinReturn |              14 |
# |          EpLenMean |            50.9 |
# |           EpLenStd |            30.5 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        9.21e+03 |
# ----------------------------------------
# ********** Iteration 9 ************
# the loss is 0.00694453
# ----------------------------------------
# |               Time |            7.21 |
# |          Iteration |               9 |
# |      AverageReturn |            47.9 |
# |          StdReturn |            18.1 |
# |          MaxReturn |              88 |
# |          MinReturn |              19 |
# |          EpLenMean |            47.9 |
# |           EpLenStd |            18.1 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.02e+04 |
# ----------------------------------------
# ********** Iteration 10 ************
# the loss is -0.000326563
# ----------------------------------------
# |               Time |             7.7 |
# |          Iteration |              10 |
# |      AverageReturn |            50.4 |
# |          StdReturn |            24.2 |
# |          MaxReturn |             102 |
# |          MinReturn |              24 |
# |          EpLenMean |            50.4 |
# |           EpLenStd |            24.2 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.12e+04 |
# ----------------------------------------
# ********** Iteration 11 ************
# the loss is 0.00365312
# ----------------------------------------
# |               Time |            8.52 |
# |          Iteration |              11 |
# |      AverageReturn |            65.2 |
# |          StdReturn |            34.1 |
# |          MaxReturn |             146 |
# |          MinReturn |              19 |
# |          EpLenMean |            65.2 |
# |           EpLenStd |            34.1 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        1.23e+04 |
# ----------------------------------------
# ********** Iteration 12 ************
# the loss is -0.00659926
# ----------------------------------------
# |               Time |            9.15 |
# |          Iteration |              12 |
# |      AverageReturn |            59.3 |
# |          StdReturn |            31.2 |
# |          MaxReturn |             128 |
# |          MinReturn |              15 |
# |          EpLenMean |            59.3 |
# |           EpLenStd |            31.2 |
# | TimestepsThisBatch |        1.07e+03 |
# |     TimestepsSoFar |        1.33e+04 |
# ----------------------------------------
# ********** Iteration 13 ************
# the loss is 0.0118187
# ----------------------------------------
# |               Time |            9.78 |
# |          Iteration |              13 |
# |      AverageReturn |            45.6 |
# |          StdReturn |            16.9 |
# |          MaxReturn |              85 |
# |          MinReturn |              16 |
# |          EpLenMean |            45.6 |
# |           EpLenStd |            16.9 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        1.43e+04 |
# ----------------------------------------
# ********** Iteration 14 ************
# the loss is 0.013306
# ----------------------------------------
# |               Time |            10.3 |
# |          Iteration |              14 |
# |      AverageReturn |            55.9 |
# |          StdReturn |            20.7 |
# |          MaxReturn |             109 |
# |          MinReturn |              31 |
# |          EpLenMean |            55.9 |
# |           EpLenStd |            20.7 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.53e+04 |
# ----------------------------------------
# ********** Iteration 15 ************
# the loss is 0.0105107
# ----------------------------------------
# |               Time |            10.9 |
# |          Iteration |              15 |
# |      AverageReturn |            63.3 |
# |          StdReturn |            22.9 |
# |          MaxReturn |             105 |
# |          MinReturn |              30 |
# |          EpLenMean |            63.3 |
# |           EpLenStd |            22.9 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        1.64e+04 |
# ----------------------------------------
# ********** Iteration 16 ************
# the loss is 0.00331512
# ----------------------------------------
# |               Time |            11.4 |
# |          Iteration |              16 |
# |      AverageReturn |            58.7 |
# |          StdReturn |              19 |
# |          MaxReturn |              96 |
# |          MinReturn |              27 |
# |          EpLenMean |            58.7 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        1.75e+04 |
# ----------------------------------------
# ********** Iteration 17 ************
# the loss is 0.0122896
# ----------------------------------------
# |               Time |            11.8 |
# |          Iteration |              17 |
# |      AverageReturn |            51.7 |
# |          StdReturn |            15.8 |
# |          MaxReturn |              82 |
# |          MinReturn |              18 |
# |          EpLenMean |            51.6 |
# |           EpLenStd |            15.8 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        1.85e+04 |
# ----------------------------------------
# ********** Iteration 18 ************
# the loss is 0.00826297
# ----------------------------------------
# |               Time |            12.3 |
# |          Iteration |              18 |
# |      AverageReturn |            58.4 |
# |          StdReturn |            21.7 |
# |          MaxReturn |             105 |
# |          MinReturn |              30 |
# |          EpLenMean |            58.4 |
# |           EpLenStd |            21.7 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        1.96e+04 |
# ----------------------------------------
# ********** Iteration 19 ************
# the loss is -0.00121431
# ----------------------------------------
# |               Time |            12.9 |
# |          Iteration |              19 |
# |      AverageReturn |            81.5 |
# |          StdReturn |            33.7 |
# |          MaxReturn |             144 |
# |          MinReturn |              40 |
# |          EpLenMean |            81.5 |
# |           EpLenStd |            33.7 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        2.06e+04 |
# ----------------------------------------
# ********** Iteration 20 ************
# the loss is 0.0046872
# ----------------------------------------
# |               Time |            13.5 |
# |          Iteration |              20 |
# |      AverageReturn |            74.9 |
# |          StdReturn |            31.3 |
# |          MaxReturn |             138 |
# |          MinReturn |              22 |
# |          EpLenMean |            74.9 |
# |           EpLenStd |            31.3 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        2.17e+04 |
# ----------------------------------------
# ********** Iteration 21 ************
# the loss is 0.0134383
# ----------------------------------------
# |               Time |              14 |
# |          Iteration |              21 |
# |      AverageReturn |            63.7 |
# |          StdReturn |              19 |
# |          MaxReturn |             103 |
# |          MinReturn |              35 |
# |          EpLenMean |            63.7 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        2.28e+04 |
# ----------------------------------------
# ********** Iteration 22 ************
# the loss is -0.00847056
# ----------------------------------------
# |               Time |            14.5 |
# |          Iteration |              22 |
# |      AverageReturn |            72.5 |
# |          StdReturn |              23 |
# |          MaxReturn |             113 |
# |          MinReturn |              40 |
# |          EpLenMean |            72.5 |
# |           EpLenStd |              23 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        2.39e+04 |
# ----------------------------------------
# ********** Iteration 23 ************
# the loss is -0.00229885
# ----------------------------------------
# |               Time |            15.1 |
# |          Iteration |              23 |
# |      AverageReturn |            77.2 |
# |          StdReturn |            30.2 |
# |          MaxReturn |             150 |
# |          MinReturn |              37 |
# |          EpLenMean |            77.2 |
# |           EpLenStd |            30.2 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        2.49e+04 |
# ----------------------------------------
# ********** Iteration 24 ************
# the loss is 0.0150217
# ----------------------------------------
# |               Time |            15.6 |
# |          Iteration |              24 |
# |      AverageReturn |            83.7 |
# |          StdReturn |            19.7 |
# |          MaxReturn |             120 |
# |          MinReturn |              52 |
# |          EpLenMean |            83.7 |
# |           EpLenStd |            19.7 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        2.59e+04 |
# ----------------------------------------
# ********** Iteration 25 ************
# the loss is -0.000239619
# ----------------------------------------
# |               Time |            16.2 |
# |          Iteration |              25 |
# |      AverageReturn |            95.8 |
# |          StdReturn |            38.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              34 |
# |          EpLenMean |            95.8 |
# |           EpLenStd |            38.5 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        2.69e+04 |
# ----------------------------------------
# ********** Iteration 26 ************
# the loss is 0.00322999
# ----------------------------------------
# |               Time |            16.8 |
# |          Iteration |              26 |
# |      AverageReturn |            85.6 |
# |          StdReturn |            31.6 |
# |          MaxReturn |             152 |
# |          MinReturn |              54 |
# |          EpLenMean |            85.6 |
# |           EpLenStd |            31.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        2.79e+04 |
# ----------------------------------------
# ********** Iteration 27 ************
# the loss is 0.0101226
# ----------------------------------------
# |               Time |            17.5 |
# |          Iteration |              27 |
# |      AverageReturn |             144 |
# |          StdReturn |            41.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              63 |
# |          EpLenMean |             144 |
# |           EpLenStd |            41.6 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |         2.9e+04 |
# ----------------------------------------
# ********** Iteration 28 ************
# the loss is -0.00408851
# ----------------------------------------
# |               Time |            18.3 |
# |          Iteration |              28 |
# |      AverageReturn |             128 |
# |          StdReturn |            59.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              37 |
# |          EpLenMean |             128 |
# |           EpLenStd |            59.4 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |           3e+04 |
# ----------------------------------------
# ********** Iteration 29 ************
# the loss is 0.00500667
# ----------------------------------------
# |               Time |              19 |
# |          Iteration |              29 |
# |      AverageReturn |             172 |
# |          StdReturn |            29.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             122 |
# |          EpLenMean |             172 |
# |           EpLenStd |            29.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |         3.1e+04 |
# ----------------------------------------
# ********** Iteration 30 ************
# the loss is -0.00249752
# ----------------------------------------
# |               Time |            19.7 |
# |          Iteration |              30 |
# |      AverageReturn |             120 |
# |          StdReturn |              49 |
# |          MaxReturn |             200 |
# |          MinReturn |              45 |
# |          EpLenMean |             120 |
# |           EpLenStd |              49 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        3.21e+04 |
# ----------------------------------------
# ********** Iteration 31 ************
# the loss is 0.0256459
# ----------------------------------------
# |               Time |            20.4 |
# |          Iteration |              31 |
# |      AverageReturn |             122 |
# |          StdReturn |            33.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              79 |
# |          EpLenMean |             122 |
# |           EpLenStd |            33.7 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        3.32e+04 |
# ----------------------------------------
# ********** Iteration 32 ************
# the loss is 0.0128052
# ----------------------------------------
# |               Time |            21.1 |
# |          Iteration |              32 |
# |      AverageReturn |             120 |
# |          StdReturn |            53.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              31 |
# |          EpLenMean |             120 |
# |           EpLenStd |            53.7 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        3.43e+04 |
# ----------------------------------------
# ********** Iteration 33 ************
# the loss is 0.0216928
# ----------------------------------------
# |               Time |            21.9 |
# |          Iteration |              33 |
# |      AverageReturn |             151 |
# |          StdReturn |            38.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              70 |
# |          EpLenMean |             151 |
# |           EpLenStd |            38.2 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        3.53e+04 |
# ----------------------------------------
# ********** Iteration 34 ************
# the loss is -0.000450816
# ----------------------------------------
# |               Time |            22.7 |
# |          Iteration |              34 |
# |      AverageReturn |             168 |
# |          StdReturn |            32.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             121 |
# |          EpLenMean |             168 |
# |           EpLenStd |            32.2 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        3.63e+04 |
# ----------------------------------------
# ********** Iteration 35 ************
# the loss is 0.00157982
# ----------------------------------------
# |               Time |            23.5 |
# |          Iteration |              35 |
# |      AverageReturn |             151 |
# |          StdReturn |            34.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              97 |
# |          EpLenMean |             151 |
# |           EpLenStd |            34.1 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        3.74e+04 |
# ----------------------------------------
# ********** Iteration 36 ************
# the loss is -0.0061436
# ----------------------------------------
# |               Time |            24.2 |
# |          Iteration |              36 |
# |      AverageReturn |             172 |
# |          StdReturn |            22.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             145 |
# |          EpLenMean |             172 |
# |           EpLenStd |            22.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        3.84e+04 |
# ----------------------------------------
# ********** Iteration 37 ************
# the loss is 0.00659663
# ----------------------------------------
# |               Time |            24.9 |
# |          Iteration |              37 |
# |      AverageReturn |             148 |
# |          StdReturn |            61.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              29 |
# |          EpLenMean |             148 |
# |           EpLenStd |            61.9 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        3.95e+04 |
# ----------------------------------------
# ********** Iteration 38 ************
# the loss is 0.00513944
# ----------------------------------------
# |               Time |            25.6 |
# |          Iteration |              38 |
# |      AverageReturn |             148 |
# |          StdReturn |            46.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              84 |
# |          EpLenMean |             148 |
# |           EpLenStd |            46.3 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        4.05e+04 |
# ----------------------------------------
# ********** Iteration 39 ************
# the loss is 0.00465926
# ----------------------------------------
# |               Time |            26.4 |
# |          Iteration |              39 |
# |      AverageReturn |             174 |
# |          StdReturn |              33 |
# |          MaxReturn |             200 |
# |          MinReturn |             120 |
# |          EpLenMean |             174 |
# |           EpLenStd |              33 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        4.15e+04 |
# ----------------------------------------
# ********** Iteration 40 ************
# the loss is 0.0256171
# ----------------------------------------
# |               Time |            27.4 |
# |          Iteration |              40 |
# |      AverageReturn |             179 |
# |          StdReturn |              47 |
# |          MaxReturn |             200 |
# |          MinReturn |              74 |
# |          EpLenMean |             179 |
# |           EpLenStd |              47 |
# | TimestepsThisBatch |        1.07e+03 |
# |     TimestepsSoFar |        4.26e+04 |
# ----------------------------------------
# ********** Iteration 41 ************
# the loss is 0.00448889
# ----------------------------------------
# |               Time |            28.2 |
# |          Iteration |              41 |
# |      AverageReturn |             185 |
# |          StdReturn |            27.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             125 |
# |          EpLenMean |             185 |
# |           EpLenStd |            27.4 |
# | TimestepsThisBatch |        1.11e+03 |
# |     TimestepsSoFar |        4.37e+04 |
# ----------------------------------------
# ********** Iteration 42 ************
# the loss is -0.00111985
# ----------------------------------------
# |               Time |            29.2 |
# |          Iteration |              42 |
# |      AverageReturn |             190 |
# |          StdReturn |            23.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             138 |
# |          EpLenMean |             190 |
# |           EpLenStd |            23.1 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        4.49e+04 |
# ----------------------------------------
# ********** Iteration 43 ************
# the loss is 0.0144184
# ----------------------------------------
# |               Time |              30 |
# |          Iteration |              43 |
# |      AverageReturn |             175 |
# |          StdReturn |            34.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             102 |
# |          EpLenMean |             175 |
# |           EpLenStd |            34.7 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        4.59e+04 |
# ----------------------------------------
# ********** Iteration 44 ************
# the loss is -0.00703714
# ----------------------------------------
# |               Time |            30.8 |
# |          Iteration |              44 |
# |      AverageReturn |             161 |
# |          StdReturn |            39.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             110 |
# |          EpLenMean |             161 |
# |           EpLenStd |            39.3 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |         4.7e+04 |
# ----------------------------------------
# ********** Iteration 45 ************
# the loss is -0.000154325
# ----------------------------------------
# |               Time |            31.6 |
# |          Iteration |              45 |
# |      AverageReturn |             184 |
# |          StdReturn |            22.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             146 |
# |          EpLenMean |             184 |
# |           EpLenStd |            22.9 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        4.81e+04 |
# ----------------------------------------
# ********** Iteration 46 ************
# the loss is 0.00522959
# ----------------------------------------
# |               Time |            32.5 |
# |          Iteration |              46 |
# |      AverageReturn |             182 |
# |          StdReturn |            32.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             182 |
# |           EpLenStd |            32.1 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        4.92e+04 |
# ----------------------------------------
# ********** Iteration 47 ************
# the loss is 0.00239709
# ----------------------------------------
# |               Time |            33.4 |
# |          Iteration |              47 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.04e+04 |
# ----------------------------------------
# ********** Iteration 48 ************
# the loss is 0.0187322
# ----------------------------------------
# |               Time |            34.2 |
# |          Iteration |              48 |
# |      AverageReturn |             182 |
# |          StdReturn |            26.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             134 |
# |          EpLenMean |             182 |
# |           EpLenStd |            26.2 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        5.15e+04 |
# ----------------------------------------
# ********** Iteration 49 ************
# the loss is 0.00428317
# ----------------------------------------
# |               Time |            35.1 |
# |          Iteration |              49 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.27e+04 |
# ----------------------------------------
# ********** Iteration 50 ************
# the loss is 0.0120927
# ----------------------------------------
# |               Time |            35.8 |
# |          Iteration |              50 |
# |      AverageReturn |             177 |
# |          StdReturn |            32.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             127 |
# |          EpLenMean |             177 |
# |           EpLenStd |            32.6 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        5.38e+04 |
# ----------------------------------------
# ********** Iteration 51 ************
# the loss is -0.00612478
# ----------------------------------------
# |               Time |            36.8 |
# |          Iteration |              51 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.21 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.21 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |         5.5e+04 |
# ----------------------------------------
# ********** Iteration 52 ************
# the loss is 0.0107623
# ----------------------------------------
# |               Time |            37.9 |
# |          Iteration |              52 |
# |      AverageReturn |             198 |
# |          StdReturn |             4.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             189 |
# |          EpLenMean |             198 |
# |           EpLenStd |             4.1 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        5.62e+04 |
# ----------------------------------------
# ********** Iteration 53 ************
# the loss is 0.00641529
# ----------------------------------------
# |               Time |            38.8 |
# |          Iteration |              53 |
# |      AverageReturn |             189 |
# |          StdReturn |              23 |
# |          MaxReturn |             200 |
# |          MinReturn |             138 |
# |          EpLenMean |             189 |
# |           EpLenStd |              23 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        5.73e+04 |
# ----------------------------------------
# ********** Iteration 54 ************
# the loss is -0.01225
# ----------------------------------------
# |               Time |            39.7 |
# |          Iteration |              54 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.85e+04 |
# ----------------------------------------
# ********** Iteration 55 ************
# the loss is 0.00908792
# ----------------------------------------
# |               Time |            40.7 |
# |          Iteration |              55 |
# |      AverageReturn |             185 |
# |          StdReturn |            32.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             185 |
# |           EpLenStd |            32.8 |
# | TimestepsThisBatch |        1.11e+03 |
# |     TimestepsSoFar |        5.96e+04 |
# ----------------------------------------
# ********** Iteration 56 ************
# the loss is 0.00457649
# ----------------------------------------
# |               Time |            41.7 |
# |          Iteration |              56 |
# |      AverageReturn |             192 |
# |          StdReturn |            16.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             155 |
# |          EpLenMean |             192 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        1.16e+03 |
# |     TimestepsSoFar |        6.08e+04 |
# ----------------------------------------
# ********** Iteration 57 ************
# the loss is -0.00654377
# ----------------------------------------
# |               Time |            42.6 |
# |          Iteration |              57 |
# |      AverageReturn |             198 |
# |          StdReturn |            3.35 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             198 |
# |           EpLenStd |            3.35 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        6.19e+04 |
# ----------------------------------------
# ********** Iteration 58 ************
# the loss is 0.00105382
# ----------------------------------------
# |               Time |            43.4 |
# |          Iteration |              58 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             126 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.6 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        6.31e+04 |
# ----------------------------------------
# ********** Iteration 59 ************
# the loss is 0.00877511
# ----------------------------------------
# |               Time |            44.6 |
# |          Iteration |              59 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        6.43e+04 |
# ----------------------------------------
# ********** Iteration 60 ************
# the loss is 0.00549403
# ----------------------------------------
# |               Time |            45.4 |
# |          Iteration |              60 |
# |      AverageReturn |             176 |
# |          StdReturn |            32.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             111 |
# |          EpLenMean |             176 |
# |           EpLenStd |            32.3 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        6.53e+04 |
# ----------------------------------------
# ********** Iteration 61 ************
# the loss is 0.00765768
# ----------------------------------------
# |               Time |            46.3 |
# |          Iteration |              61 |
# |      AverageReturn |             180 |
# |          StdReturn |            28.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             133 |
# |          EpLenMean |             180 |
# |           EpLenStd |            28.2 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        6.64e+04 |
# ----------------------------------------
# ********** Iteration 62 ************
# the loss is 0.00484962
# ----------------------------------------
# |               Time |            47.3 |
# |          Iteration |              62 |
# |      AverageReturn |             196 |
# |          StdReturn |            9.69 |
# |          MaxReturn |             200 |
# |          MinReturn |             174 |
# |          EpLenMean |             196 |
# |           EpLenStd |            9.69 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        6.76e+04 |
# ----------------------------------------
# ********** Iteration 63 ************
# the loss is -0.00674391
# ----------------------------------------
# |               Time |            48.2 |
# |          Iteration |              63 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        6.88e+04 |
# ----------------------------------------
# ********** Iteration 64 ************
# the loss is 0.00520385
# ----------------------------------------
# |               Time |            49.1 |
# |          Iteration |              64 |
# |      AverageReturn |             186 |
# |          StdReturn |            30.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             118 |
# |          EpLenMean |             186 |
# |           EpLenStd |            30.6 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        6.99e+04 |
# ----------------------------------------
# ********** Iteration 65 ************
# the loss is 0.00660023
# ----------------------------------------
# |               Time |            49.8 |
# |          Iteration |              65 |
# |      AverageReturn |             179 |
# |          StdReturn |            29.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             123 |
# |          EpLenMean |             179 |
# |           EpLenStd |            29.8 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |         7.1e+04 |
# ----------------------------------------
# ********** Iteration 66 ************
# the loss is 0.0186199
# ----------------------------------------
# |               Time |            50.9 |
# |          Iteration |              66 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             168 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.9 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        7.22e+04 |
# ----------------------------------------
# ********** Iteration 67 ************
# the loss is 0.00148079
# ----------------------------------------
# |               Time |            51.9 |
# |          Iteration |              67 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.34e+04 |
# ----------------------------------------
# ********** Iteration 68 ************
# the loss is 0.00897799
# ----------------------------------------
# |               Time |            52.8 |
# |          Iteration |              68 |
# |      AverageReturn |             190 |
# |          StdReturn |            15.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             161 |
# |          EpLenMean |             190 |
# |           EpLenStd |            15.2 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        7.45e+04 |
# ----------------------------------------
# ********** Iteration 69 ************
# the loss is 0.00236846
# ----------------------------------------
# |               Time |            53.7 |
# |          Iteration |              69 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             168 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.9 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        7.57e+04 |
# ----------------------------------------
# ********** Iteration 70 ************
# the loss is 0.010191
# ----------------------------------------
# |               Time |            54.8 |
# |          Iteration |              70 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.69e+04 |
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is 0.00616164
# ----------------------------------------
# |               Time |            55.7 |
# |          Iteration |              71 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.81e+04 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is -0.00515036
# ----------------------------------------
# |               Time |            56.6 |
# |          Iteration |              72 |
# |      AverageReturn |             194 |
# |          StdReturn |            8.86 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             194 |
# |           EpLenStd |            8.86 |
# | TimestepsThisBatch |        1.16e+03 |
# |     TimestepsSoFar |        7.92e+04 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is 0.0127718
# ----------------------------------------
# |               Time |            57.4 |
# |          Iteration |              73 |
# |      AverageReturn |             191 |
# |          StdReturn |            16.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             154 |
# |          EpLenMean |             191 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        8.04e+04 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is 0.00593974
# ----------------------------------------
# |               Time |            58.3 |
# |          Iteration |              74 |
# |      AverageReturn |             199 |
# |          StdReturn |            1.86 |
# |          MaxReturn |             200 |
# |          MinReturn |             195 |
# |          EpLenMean |             199 |
# |           EpLenStd |            1.86 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.16e+04 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is 0.0026006
# ----------------------------------------
# |               Time |            59.5 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.28e+04 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is 0.0116807
# ----------------------------------------
# |               Time |            60.4 |
# |          Iteration |              76 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             127 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.2 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        8.39e+04 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -0.00287546
# ----------------------------------------
# |               Time |            61.4 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.51e+04 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is 0.00650467
# ----------------------------------------
# |               Time |            62.4 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.63e+04 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.002553
# ----------------------------------------
# |               Time |            63.3 |
# |          Iteration |              79 |
# |      AverageReturn |             192 |
# |          StdReturn |            12.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             170 |
# |          EpLenMean |             192 |
# |           EpLenStd |            12.1 |
# | TimestepsThisBatch |        1.15e+03 |
# |     TimestepsSoFar |        8.74e+04 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -0.000883234
# ----------------------------------------
# |               Time |            64.2 |
# |          Iteration |              80 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.86e+04 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.000449948
# ----------------------------------------
# |               Time |              65 |
# |          Iteration |              81 |
# |      AverageReturn |             187 |
# |          StdReturn |            18.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             187 |
# |           EpLenStd |            18.9 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        8.98e+04 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -0.001301
# ----------------------------------------
# |               Time |            65.9 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.1e+04 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -0.00304297
# ----------------------------------------
# |               Time |            66.7 |
# |          Iteration |              83 |
# |      AverageReturn |             188 |
# |          StdReturn |            23.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             135 |
# |          EpLenMean |             188 |
# |           EpLenStd |            23.8 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        9.21e+04 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -0.00707398
# ----------------------------------------
# |               Time |            67.6 |
# |          Iteration |              84 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.98 |
# |          MaxReturn |             200 |
# |          MinReturn |             192 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.98 |
# ...
# the loss is 0.014325
# ----------------------------------------
# |               Time |            57.8 |
# |          Iteration |              71 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.34 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.34 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |        7.92e+04 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is 0.00811317
# ----------------------------------------
# |               Time |            58.7 |
# |          Iteration |              72 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             126 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.6 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        8.03e+04 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is 0.0140536
# ----------------------------------------
# |               Time |            59.4 |
# |          Iteration |              73 |
# |      AverageReturn |             177 |
# |          StdReturn |              35 |
# |          MaxReturn |             200 |
# |          MinReturn |             109 |
# |          EpLenMean |             177 |
# |           EpLenStd |              35 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        8.14e+04 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is 0.000911962
# ----------------------------------------
# |               Time |            60.4 |
# |          Iteration |              74 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.26e+04 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -0.000248729
# ----------------------------------------
# |               Time |            61.3 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.38e+04 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -0.00311189
# ----------------------------------------
# |               Time |            62.3 |
# |          Iteration |              76 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         8.5e+04 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is 0.00718618
# ----------------------------------------
# |               Time |            63.2 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.62e+04 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is 0.00539348
# ----------------------------------------
# |               Time |            64.1 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.74e+04 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.000138535
# ----------------------------------------
# |               Time |            65.1 |
# |          Iteration |              79 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.86e+04 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -0.00447988
# ----------------------------------------
# |               Time |            66.1 |
# |          Iteration |              80 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.98e+04 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.00060919
# ----------------------------------------
# |               Time |              67 |
# |          Iteration |              81 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.1e+04 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is 0.0120963
# ----------------------------------------
# |               Time |              68 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.22e+04 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -0.00393533
# ----------------------------------------
# |               Time |            68.9 |
# |          Iteration |              83 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.34e+04 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is 0.000316729
# ----------------------------------------
# |               Time |            69.8 |
# |          Iteration |              84 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.46e+04 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is 0.00391977
# ----------------------------------------
# |               Time |            70.8 |
# |          Iteration |              85 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.58e+04 |
# ----------------------------------------
# ********** Iteration 86 ************
# the loss is 0.00466321
# ----------------------------------------
# |               Time |            71.7 |
# |          Iteration |              86 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.7e+04 |
# ----------------------------------------
# ********** Iteration 87 ************
# the loss is 0.00539457
# ----------------------------------------
# |               Time |            72.7 |
# |          Iteration |              87 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.82e+04 |
# ----------------------------------------
# ********** Iteration 88 ************
# the loss is 0.00088137
# ----------------------------------------
# |               Time |            73.7 |
# |          Iteration |              88 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.94e+04 |
# ----------------------------------------
# ********** Iteration 89 ************
# the loss is -0.00368755
# ----------------------------------------
# |               Time |            74.6 |
# |          Iteration |              89 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.01e+05 |
# ----------------------------------------
# ********** Iteration 90 ************
# the loss is 0.0129473
# ----------------------------------------
# |               Time |            75.5 |
# |          Iteration |              90 |
# |      AverageReturn |             188 |
# |          StdReturn |            25.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             131 |
# |          EpLenMean |             188 |
# |           EpLenStd |            25.7 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        1.02e+05 |
# ----------------------------------------
# ********** Iteration 91 ************
# the loss is 0.00333989
# ----------------------------------------
# |               Time |            76.4 |
# |          Iteration |              91 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.03e+05 |
# ----------------------------------------
# ********** Iteration 92 ************
# the loss is -0.00332563
# ----------------------------------------
# |               Time |            77.3 |
# |          Iteration |              92 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.04e+05 |
# ----------------------------------------
# ********** Iteration 93 ************
# the loss is -0.00410316
# ----------------------------------------
# |               Time |            78.3 |
# |          Iteration |              93 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.05e+05 |
# ----------------------------------------
# ********** Iteration 94 ************
# the loss is -0.0260354
# ----------------------------------------
# |               Time |            79.2 |
# |          Iteration |              94 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.07e+05 |
# ----------------------------------------
# ********** Iteration 95 ************
# the loss is -0.00121005
# ----------------------------------------
# |               Time |            80.1 |
# |          Iteration |              95 |
# |      AverageReturn |             196 |
# |          StdReturn |            7.83 |
# |          MaxReturn |             200 |
# |          MinReturn |             179 |
# |          EpLenMean |             196 |
# |           EpLenStd |            7.83 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |        1.08e+05 |
# ----------------------------------------
# ********** Iteration 96 ************
# the loss is -0.00399362
# ----------------------------------------
# |               Time |            81.1 |
# |          Iteration |              96 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.09e+05 |
# ----------------------------------------
# ********** Iteration 97 ************
# the loss is -0.0084759
# ----------------------------------------
# |               Time |              82 |
# |          Iteration |              97 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         1.1e+05 |
# ----------------------------------------
# ********** Iteration 98 ************
# the loss is 0.00840747
# ----------------------------------------
# |               Time |            82.9 |
# |          Iteration |              98 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.11e+05 |
# ----------------------------------------
# ********** Iteration 99 ************
# the loss is -0.0051726
# ----------------------------------------
# |               Time |            83.8 |
# |          Iteration |              99 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.22 |
# |          MaxReturn |             200 |
# |          MinReturn |             186 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.22 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        1.12e+05 |
# ----------------------------------------

# %%
# !python ../train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -dna --exp_name lb_no_rtg_dna
# !python ../train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -rtg --exp_name lb_rtg_na
# Out:
# Running experiment with seed 1
# Logging data to data/lb_no_rtg_dna_CartPole-v0_10-09-2019_17-48-39/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is -21.6265
# ----------------------------------------
# |               Time |            4.52 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            13.1 |
# |          MaxReturn |              90 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        5.03e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is -23.9582
# ----------------------------------------
# |               Time |            6.35 |
# |          Iteration |               1 |
# |      AverageReturn |            26.7 |
# |          StdReturn |            15.2 |
# |          MaxReturn |             108 |
# |          MinReturn |               9 |
# |          EpLenMean |            26.7 |
# |           EpLenStd |            15.2 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is -26.4135
# ----------------------------------------
# |               Time |               8 |
# |          Iteration |               2 |
# |      AverageReturn |            30.6 |
# |          StdReturn |            16.4 |
# |          MaxReturn |             104 |
# |          MinReturn |              10 |
# |          EpLenMean |            30.6 |
# |           EpLenStd |            16.4 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.51e+04 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is -27.2094
# ----------------------------------------
# |               Time |            9.59 |
# |          Iteration |               3 |
# |      AverageReturn |            32.2 |
# |          StdReturn |            16.8 |
# |          MaxReturn |              95 |
# |          MinReturn |               9 |
# |          EpLenMean |            32.2 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.01e+04 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is -30.6178
# ----------------------------------------
# |               Time |            11.2 |
# |          Iteration |               4 |
# |      AverageReturn |            37.3 |
# |          StdReturn |            18.6 |
# |          MaxReturn |             135 |
# |          MinReturn |              11 |
# |          EpLenMean |            37.3 |
# |           EpLenStd |            18.6 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.51e+04 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is -31.21
# ----------------------------------------
# |               Time |            12.6 |
# |          Iteration |               5 |
# |      AverageReturn |            37.1 |
# |          StdReturn |            20.2 |
# |          MaxReturn |             131 |
# |          MinReturn |              12 |
# |          EpLenMean |            37.1 |
# |           EpLenStd |            20.2 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        3.01e+04 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is -31.8416
# ----------------------------------------
# |               Time |            14.1 |
# |          Iteration |               6 |
# |      AverageReturn |            41.4 |
# |          StdReturn |            18.5 |
# |          MaxReturn |             126 |
# |          MinReturn |              12 |
# |          EpLenMean |            41.4 |
# |           EpLenStd |            18.5 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        3.51e+04 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is -41.227
# ----------------------------------------
# |               Time |            15.6 |
# |          Iteration |               7 |
# |      AverageReturn |            44.7 |
# |          StdReturn |            29.7 |
# |          MaxReturn |             191 |
# |          MinReturn |              14 |
# |          EpLenMean |            44.7 |
# |           EpLenStd |            29.7 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        4.01e+04 |
# ----------------------------------------
# ********** Iteration 8 ************
# the loss is -37.9053
# ----------------------------------------
# |               Time |            17.1 |
# |          Iteration |               8 |
# |      AverageReturn |            48.1 |
# |          StdReturn |            24.3 |
# |          MaxReturn |             121 |
# |          MinReturn |              14 |
# |          EpLenMean |            48.1 |
# |           EpLenStd |            24.3 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        4.52e+04 |
# ----------------------------------------
# ********** Iteration 9 ************
# the loss is -38.7583
# ----------------------------------------
# |               Time |            18.7 |
# |          Iteration |               9 |
# |      AverageReturn |            52.7 |
# |          StdReturn |            22.3 |
# |          MaxReturn |             137 |
# |          MinReturn |              15 |
# |          EpLenMean |            52.7 |
# |           EpLenStd |            22.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        5.02e+04 |
# ----------------------------------------
# ********** Iteration 10 ************
# the loss is -43.0945
# ----------------------------------------
# |               Time |            20.2 |
# |          Iteration |              10 |
# |      AverageReturn |            54.9 |
# |          StdReturn |              28 |
# |          MaxReturn |             167 |
# |          MinReturn |              17 |
# |          EpLenMean |            54.9 |
# |           EpLenStd |              28 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        5.54e+04 |
# ----------------------------------------
# ********** Iteration 11 ************
# the loss is -43.1225
# ----------------------------------------
# |               Time |            21.6 |
# |          Iteration |              11 |
# |      AverageReturn |            56.3 |
# |          StdReturn |            28.1 |
# |          MaxReturn |             191 |
# |          MinReturn |              19 |
# |          EpLenMean |            56.3 |
# |           EpLenStd |            28.1 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        6.04e+04 |
# ----------------------------------------
# ********** Iteration 12 ************
# the loss is -39.4496
# ----------------------------------------
# |               Time |            23.1 |
# |          Iteration |              12 |
# |      AverageReturn |            54.9 |
# |          StdReturn |            23.1 |
# |          MaxReturn |             121 |
# |          MinReturn |              19 |
# |          EpLenMean |            54.9 |
# |           EpLenStd |            23.1 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        6.54e+04 |
# ----------------------------------------
# ********** Iteration 13 ************
# the loss is -46.2678
# ----------------------------------------
# |               Time |            24.7 |
# |          Iteration |              13 |
# |      AverageReturn |            61.4 |
# |          StdReturn |            30.3 |
# |          MaxReturn |             191 |
# |          MinReturn |              14 |
# |          EpLenMean |            61.4 |
# |           EpLenStd |            30.3 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        7.05e+04 |
# ----------------------------------------
# ********** Iteration 14 ************
# the loss is -45.3954
# ----------------------------------------
# |               Time |            26.4 |
# |          Iteration |              14 |
# |      AverageReturn |            64.8 |
# |          StdReturn |            26.5 |
# |          MaxReturn |             142 |
# |          MinReturn |              24 |
# |          EpLenMean |            64.8 |
# |           EpLenStd |            26.5 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        7.55e+04 |
# ----------------------------------------
# ********** Iteration 15 ************
# the loss is -42.8941
# ----------------------------------------
# |               Time |            28.1 |
# |          Iteration |              15 |
# |      AverageReturn |            62.8 |
# |          StdReturn |            24.1 |
# |          MaxReturn |             161 |
# |          MinReturn |              21 |
# |          EpLenMean |            62.8 |
# |           EpLenStd |            24.1 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        8.05e+04 |
# ----------------------------------------
# ********** Iteration 16 ************
# the loss is -48.6878
# ----------------------------------------
# |               Time |            29.9 |
# |          Iteration |              16 |
# |      AverageReturn |            71.6 |
# |          StdReturn |            27.5 |
# |          MaxReturn |             153 |
# |          MinReturn |              22 |
# |          EpLenMean |            71.6 |
# |           EpLenStd |            27.5 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        8.56e+04 |
# ----------------------------------------
# ********** Iteration 17 ************
# the loss is -55.9498
# ----------------------------------------
# |               Time |            31.8 |
# |          Iteration |              17 |
# |      AverageReturn |            75.9 |
# |          StdReturn |            38.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              17 |
# |          EpLenMean |            75.9 |
# |           EpLenStd |            38.3 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        9.06e+04 |
# ----------------------------------------
# ********** Iteration 18 ************
# the loss is -52.1407
# ----------------------------------------
# |               Time |            33.5 |
# |          Iteration |              18 |
# |      AverageReturn |            74.4 |
# |          StdReturn |            33.3 |
# |          MaxReturn |             186 |
# |          MinReturn |              32 |
# |          EpLenMean |            74.4 |
# |           EpLenStd |            33.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        9.57e+04 |
# ----------------------------------------
# ********** Iteration 19 ************
# the loss is -56.141
# ----------------------------------------
# |               Time |              35 |
# |          Iteration |              19 |
# |      AverageReturn |            76.6 |
# |          StdReturn |              38 |
# |          MaxReturn |             200 |
# |          MinReturn |              15 |
# |          EpLenMean |            76.6 |
# |           EpLenStd |              38 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        1.01e+05 |
# ----------------------------------------
# ********** Iteration 20 ************
# the loss is -61.9577
# ----------------------------------------
# |               Time |            36.4 |
# |          Iteration |              20 |
# |      AverageReturn |            89.3 |
# |          StdReturn |            39.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              28 |
# |          EpLenMean |            89.3 |
# |           EpLenStd |            39.7 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        1.06e+05 |
# ----------------------------------------
# ********** Iteration 21 ************
# the loss is -53.4046
# ----------------------------------------
# |               Time |            37.9 |
# |          Iteration |              21 |
# |      AverageReturn |            79.5 |
# |          StdReturn |            32.3 |
# |          MaxReturn |             194 |
# |          MinReturn |              29 |
# |          EpLenMean |            79.5 |
# |           EpLenStd |            32.3 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.11e+05 |
# ----------------------------------------
# ********** Iteration 22 ************
# the loss is -65.8332
# ----------------------------------------
# |               Time |            39.8 |
# |          Iteration |              22 |
# |      AverageReturn |              97 |
# |          StdReturn |            40.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              38 |
# |          EpLenMean |              97 |
# |           EpLenStd |            40.4 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        1.16e+05 |
# ----------------------------------------
# ********** Iteration 23 ************
# the loss is -67.5241
# ----------------------------------------
# |               Time |            41.4 |
# |          Iteration |              23 |
# |      AverageReturn |             100 |
# |          StdReturn |            43.2 |
# |          MaxReturn |             196 |
# |          MinReturn |              37 |
# |          EpLenMean |             100 |
# |           EpLenStd |            43.2 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        1.21e+05 |
# ----------------------------------------
# ********** Iteration 24 ************
# the loss is -76.2754
# ----------------------------------------
# |               Time |            43.3 |
# |          Iteration |              24 |
# |      AverageReturn |             111 |
# |          StdReturn |            49.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              32 |
# |          EpLenMean |             111 |
# |           EpLenStd |            49.9 |
# | TimestepsThisBatch |        5.00e+03 |
# |     TimestepsSoFar |        1.26e+05 |
# ----------------------------------------
# ********** Iteration 25 ************
# the loss is -72.9544
# ----------------------------------------
# |               Time |            44.8 |
# |          Iteration |              25 |
# |      AverageReturn |             110 |
# |          StdReturn |            44.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              45 |
# |          EpLenMean |             110 |
# |           EpLenStd |            44.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        1.31e+05 |
# ----------------------------------------
# ********** Iteration 26 ************
# the loss is -84.5777
# ----------------------------------------
# |               Time |            46.5 |
# |          Iteration |              26 |
# |      AverageReturn |             132 |
# |          StdReturn |            45.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              52 |
# |          EpLenMean |             132 |
# |           EpLenStd |            45.5 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.36e+05 |
# ----------------------------------------
# ********** Iteration 27 ************
# the loss is -86.3554
# ----------------------------------------
# |               Time |              48 |
# |          Iteration |              27 |
# |      AverageReturn |             138 |
# |          StdReturn |            44.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              45 |
# |          EpLenMean |             138 |
# |           EpLenStd |            44.3 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        1.41e+05 |
# ----------------------------------------
# ********** Iteration 28 ************
# the loss is -87.9091
# ----------------------------------------
# |               Time |            49.5 |
# |          Iteration |              28 |
# |      AverageReturn |             141 |
# |          StdReturn |            42.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              62 |
# |          EpLenMean |             141 |
# |           EpLenStd |            42.8 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        1.46e+05 |
# ----------------------------------------
# ********** Iteration 29 ************
# the loss is -98.248
# ----------------------------------------
# |               Time |            51.3 |
# |          Iteration |              29 |
# |      AverageReturn |             167 |
# |          StdReturn |            31.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              94 |
# |          EpLenMean |             167 |
# |           EpLenStd |            31.8 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.51e+05 |
# ----------------------------------------
# ********** Iteration 30 ************
# the loss is -95.6019
# ----------------------------------------
# |               Time |            53.2 |
# |          Iteration |              30 |
# |      AverageReturn |             156 |
# |          StdReturn |            45.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              44 |
# |          EpLenMean |             156 |
# |           EpLenStd |            45.1 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        1.56e+05 |
# ----------------------------------------
# ********** Iteration 31 ************
# the loss is -93.6463
# ----------------------------------------
# |               Time |            55.3 |
# |          Iteration |              31 |
# |      AverageReturn |             153 |
# |          StdReturn |            41.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              61 |
# |          EpLenMean |             153 |
# |           EpLenStd |            41.7 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        1.61e+05 |
# ----------------------------------------
# ********** Iteration 32 ************
# the loss is -91.8214
# ----------------------------------------
# |               Time |            56.8 |
# |          Iteration |              32 |
# |      AverageReturn |             152 |
# |          StdReturn |            39.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              39 |
# |          EpLenMean |             152 |
# |           EpLenStd |            39.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.66e+05 |
# ----------------------------------------
# ********** Iteration 33 ************
# the loss is -95.2134
# ----------------------------------------
# |               Time |            58.2 |
# |          Iteration |              33 |
# |      AverageReturn |             162 |
# |          StdReturn |              34 |
# |          MaxReturn |             200 |
# |          MinReturn |             101 |
# |          EpLenMean |             162 |
# |           EpLenStd |              34 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.71e+05 |
# ----------------------------------------
# ********** Iteration 34 ************
# the loss is -94.8754
# ----------------------------------------
# |               Time |            59.8 |
# |          Iteration |              34 |
# |      AverageReturn |             147 |
# |          StdReturn |            53.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              24 |
# |          EpLenMean |             147 |
# |           EpLenStd |            53.3 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        1.77e+05 |
# ----------------------------------------
# ********** Iteration 35 ************
# the loss is -91.5788
# ----------------------------------------
# |               Time |            61.3 |
# |          Iteration |              35 |
# |      AverageReturn |             153 |
# |          StdReturn |            38.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              74 |
# |          EpLenMean |             153 |
# |           EpLenStd |            38.4 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        1.82e+05 |
# ----------------------------------------
# ********** Iteration 36 ************
# the loss is -98.8928
# ----------------------------------------
# |               Time |            62.8 |
# |          Iteration |              36 |
# |      AverageReturn |             167 |
# |          StdReturn |            32.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             108 |
# |          EpLenMean |             167 |
# |           EpLenStd |            32.7 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.87e+05 |
# ----------------------------------------
# ********** Iteration 37 ************
# the loss is -103.05
# ----------------------------------------
# |               Time |            64.3 |
# |          Iteration |              37 |
# |      AverageReturn |             175 |
# |          StdReturn |              37 |
# |          MaxReturn |             200 |
# |          MinReturn |              45 |
# |          EpLenMean |             175 |
# |           EpLenStd |              37 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        1.92e+05 |
# ----------------------------------------
# ********** Iteration 38 ************
# the loss is -102.365
# ----------------------------------------
# |               Time |              66 |
# |          Iteration |              38 |
# |      AverageReturn |             174 |
# |          StdReturn |            34.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              80 |
# |          EpLenMean |             174 |
# |           EpLenStd |            34.3 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.97e+05 |
# ----------------------------------------
# ********** Iteration 39 ************
# the loss is -104.221
# ----------------------------------------
# |               Time |            67.7 |
# |          Iteration |              39 |
# |      AverageReturn |             175 |
# |          StdReturn |            38.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              63 |
# |          EpLenMean |             175 |
# |           EpLenStd |            38.7 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        2.02e+05 |
# ----------------------------------------
# ********** Iteration 40 ************
# the loss is -108.078
# ----------------------------------------
# |               Time |            69.7 |
# |          Iteration |              40 |
# |      AverageReturn |             187 |
# |          StdReturn |            22.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             117 |
# |          EpLenMean |             187 |
# |           EpLenStd |            22.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        2.07e+05 |
# ----------------------------------------
# ********** Iteration 41 ************
# the loss is -108.133
# ----------------------------------------
# |               Time |            71.7 |
# |          Iteration |              41 |
# |      AverageReturn |             188 |
# |          StdReturn |            23.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             106 |
# |          EpLenMean |             188 |
# |           EpLenStd |            23.9 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        2.12e+05 |
# ----------------------------------------
# ********** Iteration 42 ************
# the loss is -111.725
# ----------------------------------------
# |               Time |            73.8 |
# |          Iteration |              42 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             158 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.6 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        2.17e+05 |
# ----------------------------------------
# ********** Iteration 43 ************
# the loss is -112.177
# ----------------------------------------
# |               Time |            76.2 |
# |          Iteration |              43 |
# |      AverageReturn |             195 |
# |          StdReturn |            16.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             134 |
# |          EpLenMean |             195 |
# |           EpLenStd |            16.2 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        2.22e+05 |
# ----------------------------------------
# ********** Iteration 44 ************
# the loss is -112.615
# ----------------------------------------
# |               Time |            78.6 |
# |          Iteration |              44 |
# |      AverageReturn |             198 |
# |          StdReturn |            6.26 |
# |          MaxReturn |             200 |
# |          MinReturn |             175 |
# |          EpLenMean |             198 |
# |           EpLenStd |            6.26 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        2.27e+05 |
# ----------------------------------------
# ********** Iteration 45 ************
# the loss is -114.299
# ----------------------------------------
# |               Time |            81.1 |
# |          Iteration |              45 |
# |      AverageReturn |             199 |
# |          StdReturn |               5 |
# |          MaxReturn |             200 |
# |          MinReturn |             174 |
# |          EpLenMean |             199 |
# |           EpLenStd |               5 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        2.32e+05 |
# ----------------------------------------
# ********** Iteration 46 ************
# the loss is -114.049
# ----------------------------------------
# |               Time |            84.2 |
# |          Iteration |              46 |
# |      AverageReturn |             192 |
# |          StdReturn |            33.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              24 |
# |          EpLenMean |             192 |
# |           EpLenStd |            33.4 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.38e+05 |
# ----------------------------------------
# ********** Iteration 47 ************
# the loss is -115.183
# ----------------------------------------
# |               Time |            86.3 |
# |          Iteration |              47 |
# |      AverageReturn |             199 |
# |          StdReturn |            4.66 |
# |          MaxReturn |             200 |
# |          MinReturn |             179 |
# |          EpLenMean |             199 |
# |           EpLenStd |            4.66 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        2.43e+05 |
# ----------------------------------------
# ********** Iteration 48 ************
# the loss is -112.859
# ----------------------------------------
# |               Time |            88.7 |
# |          Iteration |              48 |
# |      AverageReturn |             194 |
# |          StdReturn |            18.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             128 |
# |          EpLenMean |             194 |
# |           EpLenStd |            18.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        2.48e+05 |
# ----------------------------------------
# ********** Iteration 49 ************
# the loss is -115.441
# ----------------------------------------
# |               Time |              92 |
# |          Iteration |              49 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.88 |
# |          MaxReturn |             200 |
# |          MinReturn |             185 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.88 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.53e+05 |
# ----------------------------------------
# ********** Iteration 50 ************
# the loss is -112.308
# ----------------------------------------
# |               Time |            94.6 |
# |          Iteration |              50 |
# |      AverageReturn |             190 |
# |          StdReturn |            27.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              70 |
# |          EpLenMean |             190 |
# |           EpLenStd |            27.8 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        2.58e+05 |
# ----------------------------------------
# ********** Iteration 51 ************
# the loss is -113.69
# ----------------------------------------
# |               Time |            96.5 |
# |          Iteration |              51 |
# |      AverageReturn |             187 |
# |          StdReturn |            37.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              53 |
# |          EpLenMean |             187 |
# |           EpLenStd |            37.8 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        2.63e+05 |
# ----------------------------------------
# ********** Iteration 52 ************
# the loss is -113.285
# ----------------------------------------
# |               Time |            98.2 |
# |          Iteration |              52 |
# |      AverageReturn |             191 |
# |          StdReturn |            29.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              63 |
# |          EpLenMean |             191 |
# |           EpLenStd |            29.4 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        2.68e+05 |
# ----------------------------------------
# ********** Iteration 53 ************
# the loss is -111.781
# ----------------------------------------
# |               Time |            99.9 |
# |          Iteration |              53 |
# |      AverageReturn |             190 |
# |          StdReturn |            22.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             107 |
# |          EpLenMean |             190 |
# |           EpLenStd |            22.4 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        2.73e+05 |
# ----------------------------------------
# ********** Iteration 54 ************
# the loss is -114.615
# ----------------------------------------
# |               Time |             102 |
# |          Iteration |              54 |
# |      AverageReturn |             196 |
# |          StdReturn |            14.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             133 |
# |          EpLenMean |             196 |
# |           EpLenStd |            14.1 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        2.79e+05 |
# ----------------------------------------
# ********** Iteration 55 ************
# the loss is -113.175
# ----------------------------------------
# |               Time |             103 |
# |          Iteration |              55 |
# |      AverageReturn |             186 |
# |          StdReturn |              36 |
# |          MaxReturn |             200 |
# |          MinReturn |              51 |
# |          EpLenMean |             186 |
# |           EpLenStd |              36 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.84e+05 |
# ----------------------------------------
# ********** Iteration 56 ************
# the loss is -110.957
# ----------------------------------------
# |               Time |             105 |
# |          Iteration |              56 |
# |      AverageReturn |             185 |
# |          StdReturn |            29.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              87 |
# |          EpLenMean |             185 |
# |           EpLenStd |            29.9 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        2.89e+05 |
# ----------------------------------------
# ********** Iteration 57 ************
# the loss is -114.11
# ----------------------------------------
# |               Time |             107 |
# |          Iteration |              57 |
# |      AverageReturn |             194 |
# |          StdReturn |            12.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             153 |
# |          EpLenMean |             194 |
# |           EpLenStd |            12.7 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        2.94e+05 |
# ----------------------------------------
# ********** Iteration 58 ************
# the loss is -111.769
# ----------------------------------------
# |               Time |             109 |
# |          Iteration |              58 |
# |      AverageReturn |             185 |
# |          StdReturn |            38.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              50 |
# |          EpLenMean |             185 |
# |           EpLenStd |            38.1 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        2.99e+05 |
# ----------------------------------------
# ********** Iteration 59 ************
# the loss is -113.671
# ----------------------------------------
# |               Time |             111 |
# |          Iteration |              59 |
# |      AverageReturn |             191 |
# |          StdReturn |            27.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              94 |
# |          EpLenMean |             191 |
# |           EpLenStd |            27.4 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        3.04e+05 |
# ----------------------------------------
# ********** Iteration 60 ************
# the loss is -106.555
# ----------------------------------------
# |               Time |             112 |
# |          Iteration |              60 |
# |      AverageReturn |             173 |
# |          StdReturn |            43.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              60 |
# |          EpLenMean |             173 |
# |           EpLenStd |            43.4 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        3.09e+05 |
# ----------------------------------------
# ********** Iteration 61 ************
# the loss is -113.538
# ----------------------------------------
# |               Time |             114 |
# |          Iteration |              61 |
# |      AverageReturn |             194 |
# |          StdReturn |            20.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             104 |
# |          EpLenMean |             194 |
# |           EpLenStd |            20.8 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        3.14e+05 |
# ----------------------------------------
# ********** Iteration 62 ************
# the loss is -109.07
# ----------------------------------------
# |               Time |             115 |
# |          Iteration |              62 |
# |      AverageReturn |             178 |
# |          StdReturn |            46.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              50 |
# |          EpLenMean |             178 |
# |           EpLenStd |            46.5 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        3.19e+05 |
# ----------------------------------------
# ********** Iteration 63 ************
# the loss is -112.779
# ----------------------------------------
# |               Time |             117 |
# |          Iteration |              63 |
# |      AverageReturn |             192 |
# |          StdReturn |            25.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              96 |
# |          EpLenMean |             192 |
# |           EpLenStd |            25.4 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        3.24e+05 |
# ----------------------------------------
# ********** Iteration 64 ************
# the loss is -113.182
# ----------------------------------------
# |               Time |             118 |
# |          Iteration |              64 |
# |      AverageReturn |             196 |
# |          StdReturn |            14.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             126 |
# |          EpLenMean |             196 |
# |           EpLenStd |            14.8 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        3.29e+05 |
# ----------------------------------------
# ********** Iteration 65 ************
# the loss is -111.915
# ----------------------------------------
# |               Time |             121 |
# |          Iteration |              65 |
# |      AverageReturn |             194 |
# |          StdReturn |            20.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             114 |
# |          EpLenMean |             194 |
# |           EpLenStd |            20.8 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        3.35e+05 |
# ----------------------------------------
# ********** Iteration 66 ************
# the loss is -112.386
# ----------------------------------------
# |               Time |             122 |
# |          Iteration |              66 |
# |      AverageReturn |             193 |
# |          StdReturn |            31.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              33 |
# |          EpLenMean |             193 |
# |           EpLenStd |            31.6 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         3.4e+05 |
# ----------------------------------------
# ********** Iteration 67 ************
# the loss is -111.41
# ----------------------------------------
# |               Time |             124 |
# |          Iteration |              67 |
# |      AverageReturn |             198 |
# |          StdReturn |            11.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             139 |
# |          EpLenMean |             198 |
# |           EpLenStd |            11.7 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        3.45e+05 |
# ----------------------------------------
# ********** Iteration 68 ************
# the loss is -110.801
# ----------------------------------------
# |               Time |             126 |
# |          Iteration |              68 |
# |      AverageReturn |             195 |
# |          StdReturn |            17.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             122 |
# |          EpLenMean |             195 |
# |           EpLenStd |            17.1 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |         3.5e+05 |
# ----------------------------------------
# ********** Iteration 69 ************
# the loss is -111.138
# ----------------------------------------
# |               Time |             128 |
# |          Iteration |              69 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.55e+05 |
# ----------------------------------------
# ********** Iteration 70 ************
# the loss is -111.993
# ----------------------------------------
# |               Time |             130 |
# |          Iteration |              70 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.12 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.12 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |         3.6e+05 |
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is -111.046
# ----------------------------------------
# |               Time |             131 |
# |          Iteration |              71 |
# |      AverageReturn |             199 |
# |          StdReturn |            4.04 |
# |          MaxReturn |             200 |
# |          MinReturn |             179 |
# |          EpLenMean |             199 |
# |           EpLenStd |            4.04 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        3.65e+05 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is -110.044
# ----------------------------------------
# |               Time |             133 |
# |          Iteration |              72 |
# |      AverageReturn |             191 |
# |          StdReturn |            34.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              21 |
# |          EpLenMean |             191 |
# |           EpLenStd |            34.1 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.71e+05 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is -108.405
# ----------------------------------------
# |               Time |             134 |
# |          Iteration |              73 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.87 |
# |          MaxReturn |             200 |
# |          MinReturn |             169 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.87 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        3.76e+05 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is -109.387
# ----------------------------------------
# |               Time |             136 |
# |          Iteration |              74 |
# |      AverageReturn |             199 |
# |          StdReturn |             4.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             199 |
# |           EpLenStd |             4.5 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.81e+05 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -108.549
# ----------------------------------------
# |               Time |             138 |
# |          Iteration |              75 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.66 |
# |          MaxReturn |             200 |
# |          MinReturn |             179 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.66 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        3.86e+05 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -109.91
# ----------------------------------------
# |               Time |             140 |
# |          Iteration |              76 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.99 |
# |          MaxReturn |             200 |
# |          MinReturn |             188 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.99 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.91e+05 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -107.858
# ----------------------------------------
# |               Time |             141 |
# |          Iteration |              77 |
# |      AverageReturn |             199 |
# |          StdReturn |             2.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             199 |
# |           EpLenStd |             2.5 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.96e+05 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is -107.625
# ----------------------------------------
# |               Time |             143 |
# |          Iteration |              78 |
# |      AverageReturn |             197 |
# |          StdReturn |            8.08 |
# |          MaxReturn |             200 |
# |          MinReturn |             164 |
# |          EpLenMean |             197 |
# |           EpLenStd |            8.08 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        4.02e+05 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -107.198
# ----------------------------------------
# |               Time |             145 |
# |          Iteration |              79 |
# |      AverageReturn |             196 |
# |          StdReturn |            6.69 |
# |          MaxReturn |             200 |
# |          MinReturn |             178 |
# |          EpLenMean |             196 |
# |           EpLenStd |            6.69 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        4.07e+05 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -105.914
# ----------------------------------------
# |               Time |             146 |
# |          Iteration |              80 |
# |      AverageReturn |             196 |
# |          StdReturn |            9.67 |
# |          MaxReturn |             200 |
# |          MinReturn |             156 |
# |          EpLenMean |             196 |
# |           EpLenStd |            9.67 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        4.12e+05 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -107.765
# ----------------------------------------
# |               Time |             148 |
# |          Iteration |              81 |
# |      AverageReturn |             197 |
# |          StdReturn |            5.15 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             197 |
# |           EpLenStd |            5.15 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        4.17e+05 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -104.763
# ----------------------------------------
# |               Time |             150 |
# |          Iteration |              82 |
# |      AverageReturn |             190 |
# |          StdReturn |            17.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             123 |
# |          EpLenMean |             190 |
# |           EpLenStd |            17.2 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        4.22e+05 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -104.609
# ----------------------------------------
# |               Time |             152 |
# |          Iteration |              83 |
# |      AverageReturn |             187 |
# |          StdReturn |            33.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              27 |
# |          EpLenMean |             187 |
# |           EpLenStd |            33.4 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        4.27e+05 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -102.116
# ----------------------------------------
# |               Time |             154 |
# |          Iteration |              84 |
# |      AverageReturn |             188 |
# |          StdReturn |            13.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             155 |
# |          EpLenMean |             188 |
# |           EpLenStd |            13.6 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        4.32e+05 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is -98.6371
# ...
# |          MaxReturn |             200 |
# |          MinReturn |             140 |
# |          EpLenMean |             190 |
# |           EpLenStd |            18.5 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        4.87e+05 |
# ----------------------------------------
# ********** Iteration 96 ************
# the loss is -105.457
# ----------------------------------------
# |               Time |             163 |
# |          Iteration |              96 |
# |      AverageReturn |             193 |
# |          StdReturn |            12.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             161 |
# |          EpLenMean |             193 |
# |           EpLenStd |            12.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        4.92e+05 |
# ----------------------------------------
# ********** Iteration 97 ************
# the loss is -106.34
# ----------------------------------------
# |               Time |             165 |
# |          Iteration |              97 |
# |      AverageReturn |             198 |
# |          StdReturn |            6.45 |
# |          MaxReturn |             200 |
# |          MinReturn |             172 |
# |          EpLenMean |             198 |
# |           EpLenStd |            6.45 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        4.97e+05 |
# ----------------------------------------
# ********** Iteration 98 ************
# the loss is -104.262
# ----------------------------------------
# |               Time |             166 |
# |          Iteration |              98 |
# |      AverageReturn |             195 |
# |          StdReturn |            8.83 |
# |          MaxReturn |             200 |
# |          MinReturn |             171 |
# |          EpLenMean |             195 |
# |           EpLenStd |            8.83 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        5.02e+05 |
# ----------------------------------------
# ********** Iteration 99 ************
# the loss is -105.943
# ----------------------------------------
# |               Time |             168 |
# |          Iteration |              99 |
# |      AverageReturn |             197 |
# |          StdReturn |            9.95 |
# |          MaxReturn |             200 |
# |          MinReturn |             158 |
# |          EpLenMean |             197 |
# |           EpLenStd |            9.95 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        5.08e+05 |
# ----------------------------------------
# Running experiment with seed 1
# Logging data to data/lb_rtg_dna_CartPole-v0_10-09-2019_17-57-37/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is -11.1135
# ----------------------------------------
# |               Time |            4.15 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            13.1 |
# |          MaxReturn |              90 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        5.03e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is -11.4933
# ----------------------------------------
# |               Time |            6.07 |
# |          Iteration |               1 |
# |      AverageReturn |            25.9 |
# |          StdReturn |            13.5 |
# |          MaxReturn |              73 |
# |          MinReturn |               9 |
# |          EpLenMean |            25.9 |
# |           EpLenStd |            13.5 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is -13.8604
# ----------------------------------------
# |               Time |            8.05 |
# |          Iteration |               2 |
# |      AverageReturn |            31.7 |
# |          StdReturn |            16.7 |
# |          MaxReturn |              97 |
# |          MinReturn |              10 |
# |          EpLenMean |            31.7 |
# |           EpLenStd |            16.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        1.51e+04 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is -15.8227
# ----------------------------------------
# |               Time |            10.1 |
# |          Iteration |               3 |
# |      AverageReturn |            34.6 |
# |          StdReturn |            20.5 |
# |          MaxReturn |             141 |
# |          MinReturn |              10 |
# |          EpLenMean |            34.6 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        2.01e+04 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is -15.2178
# ----------------------------------------
# |               Time |            12.5 |
# |          Iteration |               4 |
# |      AverageReturn |            36.3 |
# |          StdReturn |            18.2 |
# |          MaxReturn |             108 |
# |          MinReturn |              10 |
# |          EpLenMean |            36.3 |
# |           EpLenStd |            18.2 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        2.51e+04 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is -16.5145
# ----------------------------------------
# |               Time |            15.1 |
# |          Iteration |               5 |
# |      AverageReturn |            38.9 |
# |          StdReturn |            20.7 |
# |          MaxReturn |             119 |
# |          MinReturn |              11 |
# |          EpLenMean |            38.9 |
# |           EpLenStd |            20.7 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        3.01e+04 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is -16.2177
# ----------------------------------------
# |               Time |            17.6 |
# |          Iteration |               6 |
# |      AverageReturn |            41.3 |
# |          StdReturn |              19 |
# |          MaxReturn |             103 |
# |          MinReturn |              12 |
# |          EpLenMean |            41.3 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        3.52e+04 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is -17.0036
# ----------------------------------------
# |               Time |            19.9 |
# |          Iteration |               7 |
# |      AverageReturn |              44 |
# |          StdReturn |            19.5 |
# |          MaxReturn |             117 |
# |          MinReturn |              14 |
# |          EpLenMean |              44 |
# |           EpLenStd |            19.5 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        4.02e+04 |
# ----------------------------------------
# ********** Iteration 8 ************
# ^C
# Process Process-1:
# Traceback (most recent call last):
#   File "/Users/matthewhunt/anaconda/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/Users/matthewhunt/anaconda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "../train_pg_f18.py", line 763, in train_func
#     size=args.size
#   File "../train_pg_f18.py", line 683, in train_PG
#     paths, timesteps_this_batch = agent.sample_trajectories(itr, env)
#   File "../train_pg_f18.py", line 348, in sample_trajectories
#     path = self.sample_trajectory(env, animate_this_episode)
#   File "../train_pg_f18.py", line 368, in sample_trajectory
#     ac = self.sess.run(self.sy_sampled_ac,feed_dict = {self.sy_ob_no:[ob]})
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 767, in run
#     run_metadata_ptr)
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 940, in _run
#     if not subfeed_t.get_shape().is_compatible_with(np_val.shape):
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py", line 734, in is_compatible_with
#     other = as_shape(other)
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py", line 821, in as_shape
#     return TensorShape(shape)
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py", line 457, in __init__
#     self._dims = [as_dimension(d) for d in dims_iter]
#   File "/Users/matthewhunt/anaconda/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py", line 457, in <listcomp>
#     self._dims = [as_dimension(d) for d in dims_iter]
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "../train_pg_f18.py", line 779, in <module>
#     main()
#   File "../train_pg_f18.py", line 772, in main
#     p.join()
#   File "/Users/matthewhunt/anaconda/lib/python3.6/multiprocessing/process.py", line 121, in join
#     res = self._popen.wait(timeout)
#   File "/Users/matthewhunt/anaconda/lib/python3.6/multiprocessing/popen_fork.py", line 51, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/Users/matthewhunt/anaconda/lib/python3.6/multiprocessing/popen_fork.py", line 29, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt
#
# If you suspect this is an IPython bug, please report it at:
#     https://github.com/ipython/ipython/issues
# or send an email to the mailing list at ipython-dev@scipy.org
#
# You can print a more detailed traceback right now with "%tb", or use "%debug"
# to interactively debug it.
#
# Extra-detailed tracebacks for bug-reporting purposes can be enabled via:
#     %config Application.verbose_crash=True
#
# Running experiment with seed 1
# Logging data to data/lb_rtg_na_CartPole-v0_10-09-2019_17-58-01/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is 0.00633296
# ----------------------------------------
# |               Time |            4.12 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            13.1 |
# |          MaxReturn |              90 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        5.03e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is 0.00671735
# ----------------------------------------
# |               Time |            6.11 |
# |          Iteration |               1 |
# |      AverageReturn |            28.5 |
# |          StdReturn |            16.8 |
# |          MaxReturn |              96 |
# |          MinReturn |               9 |
# |          EpLenMean |            28.5 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is 0.0109764
# ----------------------------------------
# |               Time |            8.13 |
# |          Iteration |               2 |
# |      AverageReturn |            30.7 |
# |          StdReturn |            17.7 |
# |          MaxReturn |             117 |
# |          MinReturn |               9 |
# |          EpLenMean |            30.7 |
# |           EpLenStd |            17.7 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.51e+04 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is 0.0129354
# ----------------------------------------
# |               Time |            11.5 |
# |          Iteration |               3 |
# |      AverageReturn |            32.6 |
# |          StdReturn |            18.7 |
# |          MaxReturn |              97 |
# |          MinReturn |               8 |
# |          EpLenMean |            32.6 |
# |           EpLenStd |            18.7 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.01e+04 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is 0.0107331
# ----------------------------------------
# |               Time |            13.6 |
# |          Iteration |               4 |
# |      AverageReturn |            36.8 |
# |          StdReturn |            21.1 |
# |          MaxReturn |             117 |
# |          MinReturn |              10 |
# |          EpLenMean |            36.8 |
# |           EpLenStd |            21.1 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        2.51e+04 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is 0.0064741
# ----------------------------------------
# |               Time |            15.8 |
# |          Iteration |               5 |
# |      AverageReturn |            39.4 |
# |          StdReturn |            20.5 |
# |          MaxReturn |             117 |
# |          MinReturn |              10 |
# |          EpLenMean |            39.4 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        3.01e+04 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is 0.00601569
# ----------------------------------------
# |               Time |            18.2 |
# |          Iteration |               6 |
# |      AverageReturn |            42.9 |
# |          StdReturn |            22.8 |
# |          MaxReturn |             149 |
# |          MinReturn |              11 |
# |          EpLenMean |            42.9 |
# |           EpLenStd |            22.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        3.51e+04 |
# ----------------------------------------
# ********** Iteration 7 ************

# %%
# !python ../train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -rtg -dna --exp_name lb_rtg_dna
# Out:
# Running experiment with seed 1
# Logging data to data/lb_rtg_dna_CartPole-v0_11-09-2019_18-04-15/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is -11.1135
# ----------------------------------------
# |               Time |            5.29 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            13.1 |
# |          MaxReturn |              90 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        5.03e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is -11.4933
# ----------------------------------------
# |               Time |            7.46 |
# |          Iteration |               1 |
# |      AverageReturn |            25.9 |
# |          StdReturn |            13.5 |
# |          MaxReturn |              73 |
# |          MinReturn |               9 |
# |          EpLenMean |            25.9 |
# |           EpLenStd |            13.5 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is -13.8604
# ----------------------------------------
# |               Time |            9.77 |
# |          Iteration |               2 |
# |      AverageReturn |            31.7 |
# |          StdReturn |            16.7 |
# |          MaxReturn |              97 |
# |          MinReturn |              10 |
# |          EpLenMean |            31.7 |
# |           EpLenStd |            16.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        1.51e+04 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is -15.8227
# ----------------------------------------
# |               Time |            13.2 |
# |          Iteration |               3 |
# |      AverageReturn |            34.6 |
# |          StdReturn |            20.5 |
# |          MaxReturn |             141 |
# |          MinReturn |              10 |
# |          EpLenMean |            34.6 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        2.01e+04 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is -15.2178
# ----------------------------------------
# |               Time |            17.3 |
# |          Iteration |               4 |
# |      AverageReturn |            36.3 |
# |          StdReturn |            18.2 |
# |          MaxReturn |             108 |
# |          MinReturn |              10 |
# |          EpLenMean |            36.3 |
# |           EpLenStd |            18.2 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        2.51e+04 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is -16.5145
# ----------------------------------------
# |               Time |            21.3 |
# |          Iteration |               5 |
# |      AverageReturn |            38.9 |
# |          StdReturn |            20.7 |
# |          MaxReturn |             119 |
# |          MinReturn |              11 |
# |          EpLenMean |            38.9 |
# |           EpLenStd |            20.7 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        3.01e+04 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is -16.2177
# ----------------------------------------
# |               Time |            25.2 |
# |          Iteration |               6 |
# |      AverageReturn |            41.3 |
# |          StdReturn |              19 |
# |          MaxReturn |             103 |
# |          MinReturn |              12 |
# |          EpLenMean |            41.3 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        3.52e+04 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is -17.0036
# ----------------------------------------
# |               Time |            28.9 |
# |          Iteration |               7 |
# |      AverageReturn |              44 |
# |          StdReturn |            19.5 |
# |          MaxReturn |             117 |
# |          MinReturn |              14 |
# |          EpLenMean |              44 |
# |           EpLenStd |            19.5 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        4.02e+04 |
# ----------------------------------------
# ********** Iteration 8 ************
# the loss is -20.7707
# ----------------------------------------
# |               Time |            31.7 |
# |          Iteration |               8 |
# |      AverageReturn |            51.1 |
# |          StdReturn |            26.9 |
# |          MaxReturn |             170 |
# |          MinReturn |              13 |
# |          EpLenMean |            51.1 |
# |           EpLenStd |            26.9 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        4.52e+04 |
# ----------------------------------------
# ********** Iteration 9 ************
# the loss is -21.1773
# ----------------------------------------
# |               Time |            34.3 |
# |          Iteration |               9 |
# |      AverageReturn |            53.8 |
# |          StdReturn |            27.2 |
# |          MaxReturn |             134 |
# |          MinReturn |              15 |
# |          EpLenMean |            53.8 |
# |           EpLenStd |            27.2 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        5.02e+04 |
# ----------------------------------------
# ********** Iteration 10 ************
# the loss is -20.7253
# ----------------------------------------
# |               Time |            36.9 |
# |          Iteration |              10 |
# |      AverageReturn |            53.5 |
# |          StdReturn |            26.2 |
# |          MaxReturn |             190 |
# |          MinReturn |              20 |
# |          EpLenMean |            53.5 |
# |           EpLenStd |            26.2 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        5.53e+04 |
# ----------------------------------------
# ********** Iteration 11 ************
# the loss is -22.9673
# ----------------------------------------
# |               Time |            39.6 |
# |          Iteration |              11 |
# |      AverageReturn |            58.3 |
# |          StdReturn |            30.7 |
# |          MaxReturn |             172 |
# |          MinReturn |              14 |
# |          EpLenMean |            58.3 |
# |           EpLenStd |            30.7 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        6.03e+04 |
# ----------------------------------------
# ********** Iteration 12 ************
# the loss is -21.7902
# ----------------------------------------
# |               Time |            42.7 |
# |          Iteration |              12 |
# |      AverageReturn |            56.9 |
# |          StdReturn |              28 |
# |          MaxReturn |             200 |
# |          MinReturn |              18 |
# |          EpLenMean |            56.9 |
# |           EpLenStd |              28 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        6.53e+04 |
# ----------------------------------------
# ********** Iteration 13 ************
# the loss is -23.8115
# ----------------------------------------
# |               Time |            45.3 |
# |          Iteration |              13 |
# |      AverageReturn |              65 |
# |          StdReturn |            29.7 |
# |          MaxReturn |             190 |
# |          MinReturn |              20 |
# |          EpLenMean |              65 |
# |           EpLenStd |            29.7 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        7.04e+04 |
# ----------------------------------------
# ********** Iteration 14 ************
# the loss is -21.7185
# ----------------------------------------
# |               Time |            47.8 |
# |          Iteration |              14 |
# |      AverageReturn |            60.9 |
# |          StdReturn |              25 |
# |          MaxReturn |             141 |
# |          MinReturn |              23 |
# |          EpLenMean |            60.9 |
# |           EpLenStd |              25 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        7.55e+04 |
# ----------------------------------------
# ********** Iteration 15 ************
# the loss is -25.0157
# ----------------------------------------
# |               Time |            50.5 |
# |          Iteration |              15 |
# |      AverageReturn |            65.8 |
# |          StdReturn |              34 |
# |          MaxReturn |             200 |
# |          MinReturn |              14 |
# |          EpLenMean |            65.8 |
# |           EpLenStd |              34 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        8.05e+04 |
# ----------------------------------------
# ********** Iteration 16 ************
# the loss is -27.3577
# ----------------------------------------
# |               Time |            53.3 |
# |          Iteration |              16 |
# |      AverageReturn |              75 |
# |          StdReturn |            34.4 |
# |          MaxReturn |             181 |
# |          MinReturn |              22 |
# |          EpLenMean |              75 |
# |           EpLenStd |            34.4 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        8.56e+04 |
# ----------------------------------------
# ********** Iteration 17 ************
# the loss is -26.1647
# ----------------------------------------
# |               Time |            55.9 |
# |          Iteration |              17 |
# |      AverageReturn |            74.5 |
# |          StdReturn |            32.5 |
# |          MaxReturn |             170 |
# |          MinReturn |              22 |
# |          EpLenMean |            74.5 |
# |           EpLenStd |            32.5 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        9.07e+04 |
# ----------------------------------------
# ********** Iteration 18 ************
# the loss is -28.8124
# ----------------------------------------
# |               Time |            58.6 |
# |          Iteration |              18 |
# |      AverageReturn |              79 |
# |          StdReturn |            37.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              30 |
# |          EpLenMean |              79 |
# |           EpLenStd |            37.9 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        9.58e+04 |
# ----------------------------------------
# ********** Iteration 19 ************
# the loss is -33.3659
# ----------------------------------------
# |               Time |            61.4 |
# |          Iteration |              19 |
# |      AverageReturn |            93.2 |
# |          StdReturn |            43.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              21 |
# |          EpLenMean |            93.2 |
# |           EpLenStd |            43.9 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.01e+05 |
# ----------------------------------------
# ********** Iteration 20 ************
# the loss is -31.056
# ----------------------------------------
# |               Time |            64.5 |
# |          Iteration |              20 |
# |      AverageReturn |            89.9 |
# |          StdReturn |            37.1 |
# |          MaxReturn |             190 |
# |          MinReturn |              34 |
# |          EpLenMean |            89.9 |
# |           EpLenStd |            37.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.06e+05 |
# ----------------------------------------
# ********** Iteration 21 ************
# the loss is -35.1008
# ----------------------------------------
# |               Time |            67.5 |
# |          Iteration |              21 |
# |      AverageReturn |             101 |
# |          StdReturn |            43.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              31 |
# |          EpLenMean |             101 |
# |           EpLenStd |            43.8 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        1.11e+05 |
# ----------------------------------------
# ********** Iteration 22 ************
# the loss is -44.0923
# ----------------------------------------
# |               Time |            70.9 |
# |          Iteration |              22 |
# |      AverageReturn |             136 |
# |          StdReturn |            44.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              27 |
# |          EpLenMean |             136 |
# |           EpLenStd |            44.7 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        1.16e+05 |
# ----------------------------------------
# ********** Iteration 23 ************
# the loss is -45.3348
# ----------------------------------------
# |               Time |            74.3 |
# |          Iteration |              23 |
# |      AverageReturn |             142 |
# |          StdReturn |            45.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              48 |
# |          EpLenMean |             142 |
# |           EpLenStd |            45.9 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        1.21e+05 |
# ----------------------------------------
# ********** Iteration 24 ************
# the loss is -43.8052
# ----------------------------------------
# |               Time |            77.7 |
# |          Iteration |              24 |
# |      AverageReturn |             133 |
# |          StdReturn |            48.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              32 |
# |          EpLenMean |             133 |
# |           EpLenStd |            48.2 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        1.26e+05 |
# ----------------------------------------
# ********** Iteration 25 ************
# the loss is -43.8394
# ----------------------------------------
# |               Time |            80.9 |
# |          Iteration |              25 |
# |      AverageReturn |             135 |
# |          StdReturn |            44.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              46 |
# |          EpLenMean |             135 |
# |           EpLenStd |            44.5 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.31e+05 |
# ----------------------------------------
# ********** Iteration 26 ************
# the loss is -47.6271
# ----------------------------------------
# |               Time |            84.1 |
# |          Iteration |              26 |
# |      AverageReturn |             152 |
# |          StdReturn |            42.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              68 |
# |          EpLenMean |             152 |
# |           EpLenStd |            42.2 |
# | TimestepsThisBatch |        5.00e+03 |
# |     TimestepsSoFar |        1.36e+05 |
# ----------------------------------------
# ********** Iteration 27 ************
# the loss is -51.4497
# ----------------------------------------
# |               Time |            87.9 |
# |          Iteration |              27 |
# |      AverageReturn |             168 |
# |          StdReturn |            40.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              58 |
# |          EpLenMean |             168 |
# |           EpLenStd |            40.2 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        1.41e+05 |
# ----------------------------------------
# ********** Iteration 28 ************
# the loss is -51.4435
# ----------------------------------------
# |               Time |            91.5 |
# |          Iteration |              28 |
# |      AverageReturn |             165 |
# |          StdReturn |              45 |
# |          MaxReturn |             200 |
# |          MinReturn |              31 |
# |          EpLenMean |             165 |
# |           EpLenStd |              45 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        1.46e+05 |
# ----------------------------------------
# ********** Iteration 29 ************
# the loss is -51.375
# ----------------------------------------
# |               Time |            95.1 |
# |          Iteration |              29 |
# |      AverageReturn |             165 |
# |          StdReturn |            44.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              63 |
# |          EpLenMean |             165 |
# |           EpLenStd |            44.4 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        1.52e+05 |
# ----------------------------------------
# ********** Iteration 30 ************
# the loss is -53.9161
# ----------------------------------------
# |               Time |            98.9 |
# |          Iteration |              30 |
# |      AverageReturn |             182 |
# |          StdReturn |            33.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              87 |
# |          EpLenMean |             182 |
# |           EpLenStd |            33.8 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        1.57e+05 |
# ----------------------------------------
# ********** Iteration 31 ************
# the loss is -55.4691
# ----------------------------------------
# |               Time |             103 |
# |          Iteration |              31 |
# |      AverageReturn |             192 |
# |          StdReturn |            16.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             146 |
# |          EpLenMean |             192 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        1.62e+05 |
# ----------------------------------------
# ********** Iteration 32 ************
# the loss is -55.5237
# ----------------------------------------
# |               Time |             106 |
# |          Iteration |              32 |
# |      AverageReturn |             191 |
# |          StdReturn |            22.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             115 |
# |          EpLenMean |             191 |
# |           EpLenStd |            22.9 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        1.67e+05 |
# ----------------------------------------
# ********** Iteration 33 ************
# the loss is -56.4912
# ----------------------------------------
# |               Time |             110 |
# |          Iteration |              33 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.75 |
# |          MaxReturn |             200 |
# |          MinReturn |             173 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.75 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        1.72e+05 |
# ----------------------------------------
# ********** Iteration 34 ************
# the loss is -55.1912
# ----------------------------------------
# |               Time |             114 |
# |          Iteration |              34 |
# |      AverageReturn |             192 |
# |          StdReturn |            19.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             120 |
# |          EpLenMean |             192 |
# |           EpLenStd |            19.8 |
# | TimestepsThisBatch |        5.00e+03 |
# |     TimestepsSoFar |        1.77e+05 |
# ----------------------------------------
# ********** Iteration 35 ************
# the loss is -56.5593
# ----------------------------------------
# |               Time |             118 |
# |          Iteration |              35 |
# |      AverageReturn |             200 |
# |          StdReturn |           0.192 |
# |          MaxReturn |             200 |
# |          MinReturn |             199 |
# |          EpLenMean |             200 |
# |           EpLenStd |           0.192 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        1.82e+05 |
# ----------------------------------------
# ********** Iteration 36 ************
# the loss is -56.3134
# ----------------------------------------
# |               Time |             122 |
# |          Iteration |              36 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.84 |
# |          MaxReturn |             200 |
# |          MinReturn |             178 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.84 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        1.87e+05 |
# ----------------------------------------
# ********** Iteration 37 ************
# the loss is -54.9173
# ----------------------------------------
# |               Time |             125 |
# |          Iteration |              37 |
# |      AverageReturn |             194 |
# |          StdReturn |            10.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             161 |
# |          EpLenMean |             194 |
# |           EpLenStd |            10.9 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        1.93e+05 |
# ----------------------------------------
# ********** Iteration 38 ************
# the loss is -55.0052
# ----------------------------------------
# |               Time |             129 |
# |          Iteration |              38 |
# |      AverageReturn |             194 |
# |          StdReturn |            12.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             151 |
# |          EpLenMean |             194 |
# |           EpLenStd |            12.5 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        1.98e+05 |
# ----------------------------------------
# ********** Iteration 39 ************
# the loss is -54.78
# ----------------------------------------
# |               Time |             133 |
# |          Iteration |              39 |
# |      AverageReturn |             193 |
# |          StdReturn |            12.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             157 |
# |          EpLenMean |             193 |
# |           EpLenStd |            12.2 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.03e+05 |
# ----------------------------------------
# ********** Iteration 40 ************
# the loss is -53.6362
# ----------------------------------------
# |               Time |             137 |
# |          Iteration |              40 |
# |      AverageReturn |             191 |
# |          StdReturn |            16.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             144 |
# |          EpLenMean |             191 |
# |           EpLenStd |            16.4 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        2.08e+05 |
# ----------------------------------------
# ********** Iteration 41 ************
# the loss is -52.6575
# ----------------------------------------
# |               Time |             141 |
# |          Iteration |              41 |
# |      AverageReturn |             185 |
# |          StdReturn |              23 |
# |          MaxReturn |             200 |
# |          MinReturn |             123 |
# |          EpLenMean |             185 |
# |           EpLenStd |              23 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.13e+05 |
# ----------------------------------------
# ********** Iteration 42 ************
# the loss is -53.9577
# ----------------------------------------
# |               Time |             145 |
# |          Iteration |              42 |
# |      AverageReturn |             189 |
# |          StdReturn |            20.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             136 |
# |          EpLenMean |             189 |
# |           EpLenStd |            20.7 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        2.18e+05 |
# ----------------------------------------
# ********** Iteration 43 ************
# the loss is -53.7378
# ----------------------------------------
# |               Time |             148 |
# |          Iteration |              43 |
# |      AverageReturn |             186 |
# |          StdReturn |            22.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             134 |
# |          EpLenMean |             186 |
# |           EpLenStd |            22.7 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        2.23e+05 |
# ----------------------------------------
# ********** Iteration 44 ************
# the loss is -51.94
# ----------------------------------------
# |               Time |             153 |
# |          Iteration |              44 |
# |      AverageReturn |             183 |
# |          StdReturn |            23.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             133 |
# |          EpLenMean |             183 |
# |           EpLenStd |            23.4 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        2.28e+05 |
# ----------------------------------------
# ********** Iteration 45 ************
# the loss is -55.2797
# ----------------------------------------
# |               Time |             158 |
# |          Iteration |              45 |
# |      AverageReturn |             193 |
# |          StdReturn |            13.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             156 |
# |          EpLenMean |             193 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.33e+05 |
# ----------------------------------------
# ********** Iteration 46 ************
# the loss is -54.7763
# ----------------------------------------
# |               Time |             162 |
# |          Iteration |              46 |
# |      AverageReturn |             191 |
# |          StdReturn |            16.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             148 |
# |          EpLenMean |             191 |
# |           EpLenStd |            16.3 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        2.38e+05 |
# ----------------------------------------
# ********** Iteration 47 ************
# the loss is -56.7432
# ----------------------------------------
# |               Time |             167 |
# |          Iteration |              47 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.78 |
# |          MaxReturn |             200 |
# |          MinReturn |             170 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.78 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        2.43e+05 |
# ----------------------------------------
# ********** Iteration 48 ************
# the loss is -56.8186
# ----------------------------------------
# |               Time |             171 |
# |          Iteration |              48 |
# |      AverageReturn |             199 |
# |          StdReturn |            4.42 |
# |          MaxReturn |             200 |
# |          MinReturn |             177 |
# |          EpLenMean |             199 |
# |           EpLenStd |            4.42 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.49e+05 |
# ----------------------------------------
# ********** Iteration 49 ************
# the loss is -56.55
# ----------------------------------------
# |               Time |             176 |
# |          Iteration |              49 |
# |      AverageReturn |             198 |
# |          StdReturn |              10 |
# |          MaxReturn |             200 |
# |          MinReturn |             148 |
# |          EpLenMean |             198 |
# |           EpLenStd |              10 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        2.54e+05 |
# ----------------------------------------
# ********** Iteration 50 ************
# the loss is -57.5581
# ----------------------------------------
# |               Time |             180 |
# |          Iteration |              50 |
# |      AverageReturn |             199 |
# |          StdReturn |            3.27 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             199 |
# |           EpLenStd |            3.27 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.59e+05 |
# ----------------------------------------
# ********** Iteration 51 ************
# the loss is -57.9136
# ----------------------------------------
# |               Time |             184 |
# |          Iteration |              51 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.64e+05 |
# ----------------------------------------
# ********** Iteration 52 ************
# the loss is -57.2888
# ----------------------------------------
# |               Time |             188 |
# |          Iteration |              52 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.69e+05 |
# ----------------------------------------
# ********** Iteration 53 ************
# the loss is -57.2412
# ----------------------------------------
# |               Time |             191 |
# |          Iteration |              53 |
# |      AverageReturn |             200 |
# |          StdReturn |            2.31 |
# |          MaxReturn |             200 |
# |          MinReturn |             188 |
# |          EpLenMean |             200 |
# |           EpLenStd |            2.31 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        2.75e+05 |
# ----------------------------------------
# ********** Iteration 54 ************
# the loss is -57.5519
# ----------------------------------------
# |               Time |             195 |
# |          Iteration |              54 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         2.8e+05 |
# ----------------------------------------
# ********** Iteration 55 ************
# the loss is -57.5455
# ----------------------------------------
# |               Time |             199 |
# |          Iteration |              55 |
# |      AverageReturn |             198 |
# |          StdReturn |               6 |
# |          MaxReturn |             200 |
# |          MinReturn |             177 |
# |          EpLenMean |             198 |
# |           EpLenStd |               6 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        2.85e+05 |
# ----------------------------------------
# ********** Iteration 56 ************
# the loss is -57.0504
# ----------------------------------------
# |               Time |             203 |
# |          Iteration |              56 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         2.9e+05 |
# ----------------------------------------
# ********** Iteration 57 ************
# the loss is -57.3659
# ----------------------------------------
# |               Time |             207 |
# |          Iteration |              57 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.19 |
# |          MaxReturn |             200 |
# |          MinReturn |             173 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.19 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        2.95e+05 |
# ----------------------------------------
# ********** Iteration 58 ************
# the loss is -56.7629
# ----------------------------------------
# |               Time |             211 |
# |          Iteration |              58 |
# |      AverageReturn |             198 |
# |          StdReturn |            7.07 |
# |          MaxReturn |             200 |
# |          MinReturn |             164 |
# |          EpLenMean |             198 |
# |           EpLenStd |            7.07 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |           3e+05 |
# ----------------------------------------
# ********** Iteration 59 ************
# the loss is -56.0049
# ----------------------------------------
# |               Time |             215 |
# |          Iteration |              59 |
# |      AverageReturn |             186 |
# |          StdReturn |            43.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              14 |
# |          EpLenMean |             186 |
# |           EpLenStd |            43.2 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.06e+05 |
# ----------------------------------------
# ********** Iteration 60 ************
# the loss is -56.381
# ----------------------------------------
# |               Time |             218 |
# |          Iteration |              60 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.15 |
# |          MaxReturn |             200 |
# |          MinReturn |             178 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.15 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        3.11e+05 |
# ----------------------------------------
# ********** Iteration 61 ************
# the loss is -54.1749
# ----------------------------------------
# |               Time |             222 |
# |          Iteration |              61 |
# |      AverageReturn |             188 |
# |          StdReturn |            14.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             148 |
# |          EpLenMean |             188 |
# |           EpLenStd |            14.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        3.16e+05 |
# ----------------------------------------
# ********** Iteration 62 ************
# the loss is -52.3782
# ----------------------------------------
# |               Time |             226 |
# |          Iteration |              62 |
# |      AverageReturn |             175 |
# |          StdReturn |            37.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              29 |
# |          EpLenMean |             175 |
# |           EpLenStd |            37.4 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        3.21e+05 |
# ----------------------------------------
# ********** Iteration 63 ************
# the loss is -54.8408
# ----------------------------------------
# |               Time |             229 |
# |          Iteration |              63 |
# |      AverageReturn |             192 |
# |          StdReturn |            8.59 |
# |          MaxReturn |             200 |
# |          MinReturn |             171 |
# |          EpLenMean |             192 |
# |           EpLenStd |            8.59 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        3.26e+05 |
# ----------------------------------------
# ********** Iteration 64 ************
# the loss is -53.4028
# ----------------------------------------
# |               Time |             233 |
# |          Iteration |              64 |
# |      AverageReturn |             185 |
# |          StdReturn |            21.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             185 |
# |           EpLenStd |            21.4 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        3.31e+05 |
# ----------------------------------------
# ********** Iteration 65 ************
# the loss is -54.7975
# ----------------------------------------
# |               Time |             237 |
# |          Iteration |              65 |
# |      AverageReturn |             192 |
# |          StdReturn |            15.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             125 |
# |          EpLenMean |             192 |
# |           EpLenStd |            15.9 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.36e+05 |
# ----------------------------------------
# ********** Iteration 66 ************
# the loss is -54.3484
# ----------------------------------------
# |               Time |             240 |
# |          Iteration |              66 |
# |      AverageReturn |             190 |
# |          StdReturn |            18.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             119 |
# |          EpLenMean |             190 |
# |           EpLenStd |            18.1 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        3.41e+05 |
# ----------------------------------------
# ********** Iteration 67 ************
# the loss is -54.0092
# ----------------------------------------
# |               Time |             244 |
# |          Iteration |              67 |
# |      AverageReturn |             187 |
# |          StdReturn |            32.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              27 |
# |          EpLenMean |             187 |
# |           EpLenStd |            32.6 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        3.46e+05 |
# ----------------------------------------
# ********** Iteration 68 ************
# the loss is -54.9299
# ----------------------------------------
# |               Time |             248 |
# |          Iteration |              68 |
# |      AverageReturn |             189 |
# |          StdReturn |              31 |
# |          MaxReturn |             200 |
# |          MinReturn |              43 |
# |          EpLenMean |             189 |
# |           EpLenStd |              31 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        3.52e+05 |
# ----------------------------------------
# ********** Iteration 69 ************
# the loss is -54.3897
# ----------------------------------------
# |               Time |             253 |
# |          Iteration |              69 |
# |      AverageReturn |             190 |
# |          StdReturn |            20.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              96 |
# |          EpLenMean |             190 |
# |           EpLenStd |            20.9 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        3.57e+05 |
# ----------------------------------------
# ********** Iteration 70 ************
# the loss is -54.763
# ----------------------------------------
# |               Time |             258 |
# |          Iteration |              70 |
# |      AverageReturn |             194 |
# |          StdReturn |            15.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             127 |
# |          EpLenMean |             194 |
# |           EpLenStd |            15.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        3.62e+05 |
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is -54.7301
# ----------------------------------------
# |               Time |             264 |
# |          Iteration |              71 |
# |      AverageReturn |             193 |
# |          StdReturn |            12.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             156 |
# |          EpLenMean |             193 |
# |           EpLenStd |            12.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        3.67e+05 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is -55.818
# ----------------------------------------
# |               Time |             269 |
# |          Iteration |              72 |
# |      AverageReturn |             196 |
# |          StdReturn |            10.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             162 |
# |          EpLenMean |             196 |
# |           EpLenStd |            10.7 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        3.72e+05 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is -56.053
# ----------------------------------------
# |               Time |             274 |
# |          Iteration |              73 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.78 |
# |          MaxReturn |             200 |
# |          MinReturn |             187 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.78 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        3.77e+05 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is -55.965
# ----------------------------------------
# |               Time |             278 |
# |          Iteration |              74 |
# |      AverageReturn |             200 |
# |          StdReturn |            1.35 |
# |          MaxReturn |             200 |
# |          MinReturn |             193 |
# |          EpLenMean |             200 |
# |           EpLenStd |            1.35 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        3.82e+05 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -56.5787
# ----------------------------------------
# |               Time |             282 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |           0.192 |
# |          MaxReturn |             200 |
# |          MinReturn |             199 |
# |          EpLenMean |             200 |
# |           EpLenStd |           0.192 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.87e+05 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -56.3677
# ----------------------------------------
# |               Time |             286 |
# |          Iteration |              76 |
# |      AverageReturn |             200 |
# |          StdReturn |            1.73 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             200 |
# |           EpLenStd |            1.73 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        3.93e+05 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -56.0641
# ----------------------------------------
# |               Time |             290 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.98e+05 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is -55.8101
# ----------------------------------------
# |               Time |             294 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.03e+05 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -56.5496
# ----------------------------------------
# |               Time |             298 |
# |          Iteration |              79 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.08e+05 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -55.9267
# ----------------------------------------
# |               Time |             302 |
# |          Iteration |              80 |
# |      AverageReturn |             197 |
# |          StdReturn |            13.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             128 |
# |          EpLenMean |             197 |
# |           EpLenStd |            13.8 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        4.13e+05 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -55.0503
# ----------------------------------------
# |               Time |             305 |
# |          Iteration |              81 |
# |      AverageReturn |             194 |
# |          StdReturn |            24.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              73 |
# |          EpLenMean |             194 |
# |           EpLenStd |            24.9 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        4.18e+05 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -56.9443
# ----------------------------------------
# |               Time |             309 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.24e+05 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -54.5184
# ----------------------------------------
# |               Time |             313 |
# |          Iteration |              83 |
# |      AverageReturn |             184 |
# |          StdReturn |            45.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              32 |
# |          EpLenMean |             184 |
# |           EpLenStd |            45.5 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        4.29e+05 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -55.8132
# ----------------------------------------
# |               Time |             317 |
# |          Iteration |              84 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.34e+05 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is -56.1984
# ...
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is -50.6684
# ----------------------------------------
# |               Time |             272 |
# |          Iteration |              71 |
# |      AverageReturn |             198 |
# |          StdReturn |             6.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             170 |
# |          EpLenMean |             198 |
# |           EpLenStd |             6.7 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        3.68e+05 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is -51.3109
# ----------------------------------------
# |               Time |             276 |
# |          Iteration |              72 |
# |      AverageReturn |             198 |
# |          StdReturn |            9.04 |
# |          MaxReturn |             200 |
# |          MinReturn |             153 |
# |          EpLenMean |             198 |
# |           EpLenStd |            9.04 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        3.73e+05 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is -50.7028
# ----------------------------------------
# |               Time |             280 |
# |          Iteration |              73 |
# |      AverageReturn |             198 |
# |          StdReturn |            7.88 |
# |          MaxReturn |             200 |
# |          MinReturn |             159 |
# |          EpLenMean |             198 |
# |           EpLenStd |            7.88 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        3.78e+05 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is -50.0262
# ----------------------------------------
# |               Time |             284 |
# |          Iteration |              74 |
# |      AverageReturn |             191 |
# |          StdReturn |            17.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             138 |
# |          EpLenMean |             191 |
# |           EpLenStd |            17.4 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.83e+05 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -49.7306
# ----------------------------------------
# |               Time |             287 |
# |          Iteration |              75 |
# |      AverageReturn |             195 |
# |          StdReturn |            16.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             132 |
# |          EpLenMean |             195 |
# |           EpLenStd |            16.5 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        3.88e+05 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -50.1204
# ----------------------------------------
# |               Time |             291 |
# |          Iteration |              76 |
# |      AverageReturn |             195 |
# |          StdReturn |            13.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             148 |
# |          EpLenMean |             195 |
# |           EpLenStd |            13.7 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        3.94e+05 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -49.9173
# ----------------------------------------
# |               Time |             295 |
# |          Iteration |              77 |
# |      AverageReturn |             196 |
# |          StdReturn |            11.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             143 |
# |          EpLenMean |             196 |
# |           EpLenStd |            11.7 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        3.99e+05 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is -50.865
# ----------------------------------------
# |               Time |             300 |
# |          Iteration |              78 |
# |      AverageReturn |             198 |
# |          StdReturn |            8.26 |
# |          MaxReturn |             200 |
# |          MinReturn |             157 |
# |          EpLenMean |             198 |
# |           EpLenStd |            8.26 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        4.04e+05 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -51.105
# ----------------------------------------
# |               Time |             305 |
# |          Iteration |              79 |
# |      AverageReturn |             200 |
# |          StdReturn |            1.73 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             200 |
# |           EpLenStd |            1.73 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        4.09e+05 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -50.312
# ----------------------------------------
# |               Time |             310 |
# |          Iteration |              80 |
# |      AverageReturn |             196 |
# |          StdReturn |            10.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             196 |
# |           EpLenStd |            10.9 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        4.14e+05 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -49.8077
# ----------------------------------------
# |               Time |             315 |
# |          Iteration |              81 |
# |      AverageReturn |             197 |
# |          StdReturn |            10.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             157 |
# |          EpLenMean |             197 |
# |           EpLenStd |            10.3 |
# | TimestepsThisBatch |        5.12e+03 |
# |     TimestepsSoFar |        4.19e+05 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -50.2255
# ----------------------------------------
# |               Time |             319 |
# |          Iteration |              82 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.38 |
# |          MaxReturn |             200 |
# |          MinReturn |             172 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.38 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        4.24e+05 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -50.6092
# ----------------------------------------
# |               Time |             323 |
# |          Iteration |              83 |
# |      AverageReturn |             200 |
# |          StdReturn |           0.192 |
# |          MaxReturn |             200 |
# |          MinReturn |             199 |
# |          EpLenMean |             200 |
# |           EpLenStd |           0.192 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         4.3e+05 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -50.4079
# ----------------------------------------
# |               Time |             327 |
# |          Iteration |              84 |
# |      AverageReturn |             198 |
# |          StdReturn |            8.27 |
# |          MaxReturn |             200 |
# |          MinReturn |             157 |
# |          EpLenMean |             198 |
# |           EpLenStd |            8.27 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        4.35e+05 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is -50.066
# ----------------------------------------
# |               Time |             330 |
# |          Iteration |              85 |
# |      AverageReturn |             200 |
# |          StdReturn |             2.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             187 |
# |          EpLenMean |             200 |
# |           EpLenStd |             2.5 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |         4.4e+05 |
# ----------------------------------------
# ********** Iteration 86 ************
# the loss is -50.4663
# ----------------------------------------
# |               Time |             334 |
# |          Iteration |              86 |
# |      AverageReturn |             199 |
# |          StdReturn |               5 |
# |          MaxReturn |             200 |
# |          MinReturn |             174 |
# |          EpLenMean |             199 |
# |           EpLenStd |               5 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        4.45e+05 |
# ----------------------------------------
# ********** Iteration 87 ************
# the loss is -49.4569
# ----------------------------------------
# |               Time |             338 |
# |          Iteration |              87 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         4.5e+05 |
# ----------------------------------------
# ********** Iteration 88 ************
# the loss is -49.7382
# ----------------------------------------
# |               Time |             342 |
# |          Iteration |              88 |
# |      AverageReturn |             198 |
# |          StdReturn |            8.88 |
# |          MaxReturn |             200 |
# |          MinReturn |             154 |
# |          EpLenMean |             198 |
# |           EpLenStd |            8.88 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        4.55e+05 |
# ----------------------------------------
# ********** Iteration 89 ************
# the loss is -48.9093
# ----------------------------------------
# |               Time |             346 |
# |          Iteration |              89 |
# |      AverageReturn |             199 |
# |          StdReturn |            6.92 |
# |          MaxReturn |             200 |
# |          MinReturn |             164 |
# |          EpLenMean |             199 |
# |           EpLenStd |            6.92 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        4.61e+05 |
# ----------------------------------------
# ********** Iteration 90 ************
# the loss is -50.1393
# ----------------------------------------
# |               Time |             351 |
# |          Iteration |              90 |
# |      AverageReturn |             199 |
# |          StdReturn |            6.73 |
# |          MaxReturn |             200 |
# |          MinReturn |             165 |
# |          EpLenMean |             199 |
# |           EpLenStd |            6.73 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        4.66e+05 |
# ----------------------------------------
# ********** Iteration 91 ************
# the loss is -49.1106
# ----------------------------------------
# |               Time |             355 |
# |          Iteration |              91 |
# |      AverageReturn |             197 |
# |          StdReturn |             7.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             172 |
# |          EpLenMean |             197 |
# |           EpLenStd |             7.9 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        4.71e+05 |
# ----------------------------------------
# ********** Iteration 92 ************
# the loss is -48.5808
# ----------------------------------------
# |               Time |             359 |
# |          Iteration |              92 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             158 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        4.76e+05 |
# ----------------------------------------
# ********** Iteration 93 ************
# the loss is -48.1698
# ----------------------------------------
# |               Time |             363 |
# |          Iteration |              93 |
# |      AverageReturn |             194 |
# |          StdReturn |            14.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             156 |
# |          EpLenMean |             194 |
# |           EpLenStd |            14.2 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        4.81e+05 |
# ----------------------------------------
# ********** Iteration 94 ************
# the loss is -48.2751
# ----------------------------------------
# |               Time |             367 |
# |          Iteration |              94 |
# |      AverageReturn |             194 |
# |          StdReturn |            12.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             154 |
# |          EpLenMean |             194 |
# |           EpLenStd |            12.2 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        4.86e+05 |
# ----------------------------------------
# ********** Iteration 95 ************
# the loss is -48.8291
# ----------------------------------------
# |               Time |             372 |
# |          Iteration |              95 |
# |      AverageReturn |             196 |
# |          StdReturn |            9.21 |
# |          MaxReturn |             200 |
# |          MinReturn |             162 |
# |          EpLenMean |             196 |
# |           EpLenStd |            9.21 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        4.91e+05 |
# ----------------------------------------
# ********** Iteration 96 ************
# the loss is -48.811
# ----------------------------------------
# |               Time |             378 |
# |          Iteration |              96 |
# |      AverageReturn |             196 |
# |          StdReturn |            12.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             142 |
# |          EpLenMean |             196 |
# |           EpLenStd |            12.5 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        4.96e+05 |
# ----------------------------------------
# ********** Iteration 97 ************
# the loss is -50.0424
# ----------------------------------------
# |               Time |             383 |
# |          Iteration |              97 |
# |      AverageReturn |             200 |
# |          StdReturn |            1.73 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             200 |
# |           EpLenStd |            1.73 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        5.01e+05 |
# ----------------------------------------
# ********** Iteration 98 ************
# the loss is -48.2873
# ----------------------------------------
# |               Time |             387 |
# |          Iteration |              98 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        5.07e+05 |
# ----------------------------------------
# ********** Iteration 99 ************
# the loss is -48.2532
# ----------------------------------------
# |               Time |             391 |
# |          Iteration |              99 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.58 |
# |          MaxReturn |             200 |
# |          MinReturn |             171 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.58 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        5.12e+05 |
# ----------------------------------------

# %%
# !python ../train_pg_f18.py CartPole-v0 -n 100 -b 5000 -e 3 -rtg --exp_name lb_rtg_na
# Out:
# Running experiment with seed 1
# Logging data to data/lb_rtg_na_CartPole-v0_11-09-2019_17-08-07/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is 0.00633296
# ----------------------------------------
# |               Time |            4.34 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            13.1 |
# |          MaxReturn |              90 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            13.1 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        5.03e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is 0.00671735
# ----------------------------------------
# |               Time |            6.41 |
# |          Iteration |               1 |
# |      AverageReturn |            28.5 |
# |          StdReturn |            16.8 |
# |          MaxReturn |              96 |
# |          MinReturn |               9 |
# |          EpLenMean |            28.5 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |           1e+04 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is 0.0109764
# ----------------------------------------
# |               Time |            8.54 |
# |          Iteration |               2 |
# |      AverageReturn |            30.7 |
# |          StdReturn |            17.7 |
# |          MaxReturn |             117 |
# |          MinReturn |               9 |
# |          EpLenMean |            30.7 |
# |           EpLenStd |            17.7 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.51e+04 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is 0.0129354
# ----------------------------------------
# |               Time |              11 |
# |          Iteration |               3 |
# |      AverageReturn |            32.6 |
# |          StdReturn |            18.7 |
# |          MaxReturn |              97 |
# |          MinReturn |               8 |
# |          EpLenMean |            32.6 |
# |           EpLenStd |            18.7 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        2.01e+04 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is 0.0107331
# ----------------------------------------
# |               Time |            13.5 |
# |          Iteration |               4 |
# |      AverageReturn |            36.8 |
# |          StdReturn |            21.1 |
# |          MaxReturn |             117 |
# |          MinReturn |              10 |
# |          EpLenMean |            36.8 |
# |           EpLenStd |            21.1 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |        2.51e+04 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is 0.0064741
# ----------------------------------------
# |               Time |            15.7 |
# |          Iteration |               5 |
# |      AverageReturn |            39.4 |
# |          StdReturn |            20.5 |
# |          MaxReturn |             117 |
# |          MinReturn |              10 |
# |          EpLenMean |            39.4 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        3.01e+04 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is 0.00601569
# ----------------------------------------
# |               Time |              18 |
# |          Iteration |               6 |
# |      AverageReturn |            42.9 |
# |          StdReturn |            22.8 |
# |          MaxReturn |             149 |
# |          MinReturn |              11 |
# |          EpLenMean |            42.9 |
# |           EpLenStd |            22.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        3.51e+04 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is 0.00596925
# ----------------------------------------
# |               Time |            20.3 |
# |          Iteration |               7 |
# |      AverageReturn |            42.1 |
# |          StdReturn |            18.9 |
# |          MaxReturn |             124 |
# |          MinReturn |              12 |
# |          EpLenMean |            42.1 |
# |           EpLenStd |            18.9 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        4.02e+04 |
# ----------------------------------------
# ********** Iteration 8 ************
# the loss is 0.00441896
# ----------------------------------------
# |               Time |            22.6 |
# |          Iteration |               8 |
# |      AverageReturn |            49.6 |
# |          StdReturn |            23.4 |
# |          MaxReturn |             115 |
# |          MinReturn |              13 |
# |          EpLenMean |            49.6 |
# |           EpLenStd |            23.4 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        4.52e+04 |
# ----------------------------------------
# ********** Iteration 9 ************
# the loss is 0.00719751
# ----------------------------------------
# |               Time |            25.4 |
# |          Iteration |               9 |
# |      AverageReturn |            51.1 |
# |          StdReturn |            25.8 |
# |          MaxReturn |             141 |
# |          MinReturn |              10 |
# |          EpLenMean |            51.1 |
# |           EpLenStd |            25.8 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        5.02e+04 |
# ----------------------------------------
# ********** Iteration 10 ************
# the loss is 0.00694792
# ----------------------------------------
# |               Time |            27.9 |
# |          Iteration |              10 |
# |      AverageReturn |            48.2 |
# |          StdReturn |            24.3 |
# |          MaxReturn |             129 |
# |          MinReturn |              18 |
# |          EpLenMean |            48.2 |
# |           EpLenStd |            24.3 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        5.52e+04 |
# ----------------------------------------
# ********** Iteration 11 ************
# the loss is 0.00122955
# ----------------------------------------
# |               Time |            30.4 |
# |          Iteration |              11 |
# |      AverageReturn |            57.7 |
# |          StdReturn |            26.3 |
# |          MaxReturn |             181 |
# |          MinReturn |              19 |
# |          EpLenMean |            57.7 |
# |           EpLenStd |            26.3 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        6.02e+04 |
# ----------------------------------------
# ********** Iteration 12 ************
# the loss is 0.00103593
# ----------------------------------------
# |               Time |            32.6 |
# |          Iteration |              12 |
# |      AverageReturn |              53 |
# |          StdReturn |            20.9 |
# |          MaxReturn |             128 |
# |          MinReturn |              19 |
# |          EpLenMean |              53 |
# |           EpLenStd |            20.9 |
# | TimestepsThisBatch |        5.03e+03 |
# |     TimestepsSoFar |        6.52e+04 |
# ----------------------------------------
# ********** Iteration 13 ************
# the loss is 0.00787716
# ----------------------------------------
# |               Time |            35.1 |
# |          Iteration |              13 |
# |      AverageReturn |            56.4 |
# |          StdReturn |            23.8 |
# |          MaxReturn |             123 |
# |          MinReturn |              21 |
# |          EpLenMean |            56.4 |
# |           EpLenStd |            23.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        7.03e+04 |
# ----------------------------------------
# ********** Iteration 14 ************
# the loss is 0.00285374
# ----------------------------------------
# |               Time |            38.1 |
# |          Iteration |              14 |
# |      AverageReturn |            63.7 |
# |          StdReturn |            31.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              20 |
# |          EpLenMean |            63.7 |
# |           EpLenStd |            31.6 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        7.53e+04 |
# ----------------------------------------
# ********** Iteration 15 ************
# the loss is 0.0120238
# ----------------------------------------
# |               Time |            40.5 |
# |          Iteration |              15 |
# |      AverageReturn |              57 |
# |          StdReturn |            24.7 |
# |          MaxReturn |             145 |
# |          MinReturn |              16 |
# |          EpLenMean |              57 |
# |           EpLenStd |            24.7 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        8.03e+04 |
# ----------------------------------------
# ********** Iteration 16 ************
# the loss is 0.00430104
# ----------------------------------------
# |               Time |            43.1 |
# |          Iteration |              16 |
# |      AverageReturn |              69 |
# |          StdReturn |            34.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              24 |
# |          EpLenMean |              69 |
# |           EpLenStd |            34.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        8.53e+04 |
# ----------------------------------------
# ********** Iteration 17 ************
# the loss is -0.00393832
# ----------------------------------------
# |               Time |            45.5 |
# |          Iteration |              17 |
# |      AverageReturn |            64.8 |
# |          StdReturn |            25.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              24 |
# |          EpLenMean |            64.8 |
# |           EpLenStd |            25.9 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        9.04e+04 |
# ----------------------------------------
# ********** Iteration 18 ************
# the loss is 0.00354067
# ----------------------------------------
# |               Time |            48.4 |
# |          Iteration |              18 |
# |      AverageReturn |            64.7 |
# |          StdReturn |            24.7 |
# |          MaxReturn |             167 |
# |          MinReturn |              28 |
# |          EpLenMean |            64.7 |
# |           EpLenStd |            24.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        9.54e+04 |
# ----------------------------------------
# ********** Iteration 19 ************
# the loss is 0.0037562
# ----------------------------------------
# |               Time |            51.2 |
# |          Iteration |              19 |
# |      AverageReturn |            69.5 |
# |          StdReturn |            28.2 |
# |          MaxReturn |             165 |
# |          MinReturn |              20 |
# |          EpLenMean |            69.5 |
# |           EpLenStd |            28.2 |
# | TimestepsThisBatch |           5e+03 |
# |     TimestepsSoFar |           1e+05 |
# ----------------------------------------
# ********** Iteration 20 ************
# the loss is 0.00727612
# ----------------------------------------
# |               Time |            54.4 |
# |          Iteration |              20 |
# |      AverageReturn |            75.9 |
# |          StdReturn |            36.2 |
# |          MaxReturn |             171 |
# |          MinReturn |              25 |
# |          EpLenMean |            75.9 |
# |           EpLenStd |            36.2 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        1.06e+05 |
# ----------------------------------------
# ********** Iteration 21 ************
# the loss is -0.000647883
# ----------------------------------------
# |               Time |            57.4 |
# |          Iteration |              21 |
# |      AverageReturn |              76 |
# |          StdReturn |            34.8 |
# |          MaxReturn |             195 |
# |          MinReturn |              26 |
# |          EpLenMean |              76 |
# |           EpLenStd |            34.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.11e+05 |
# ----------------------------------------
# ********** Iteration 22 ************
# the loss is 0.00636275
# ----------------------------------------
# |               Time |            61.1 |
# |          Iteration |              22 |
# |      AverageReturn |              82 |
# |          StdReturn |            36.3 |
# |          MaxReturn |             193 |
# |          MinReturn |              27 |
# |          EpLenMean |              82 |
# |           EpLenStd |            36.3 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        1.16e+05 |
# ----------------------------------------
# ********** Iteration 23 ************
# the loss is 0.00191538
# ----------------------------------------
# |               Time |            63.9 |
# |          Iteration |              23 |
# |      AverageReturn |            84.3 |
# |          StdReturn |            35.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              25 |
# |          EpLenMean |            84.3 |
# |           EpLenStd |            35.7 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        1.21e+05 |
# ----------------------------------------
# ********** Iteration 24 ************
# the loss is -7.70719e-05
# ----------------------------------------
# |               Time |            66.8 |
# |          Iteration |              24 |
# |      AverageReturn |            89.7 |
# |          StdReturn |            38.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              26 |
# |          EpLenMean |            89.7 |
# |           EpLenStd |            38.1 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.26e+05 |
# ----------------------------------------
# ********** Iteration 25 ************
# the loss is 0.00109073
# ----------------------------------------
# |               Time |            69.7 |
# |          Iteration |              25 |
# |      AverageReturn |            95.2 |
# |          StdReturn |            41.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              25 |
# |          EpLenMean |            95.2 |
# |           EpLenStd |            41.3 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        1.31e+05 |
# ----------------------------------------
# ********** Iteration 26 ************
# the loss is 0.00764464
# ----------------------------------------
# |               Time |            72.7 |
# |          Iteration |              26 |
# |      AverageReturn |             110 |
# |          StdReturn |            50.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              32 |
# |          EpLenMean |             110 |
# |           EpLenStd |            50.6 |
# | TimestepsThisBatch |        5.05e+03 |
# |     TimestepsSoFar |        1.36e+05 |
# ----------------------------------------
# ********** Iteration 27 ************
# the loss is -0.00349169
# ----------------------------------------
# |               Time |            75.7 |
# |          Iteration |              27 |
# |      AverageReturn |             108 |
# |          StdReturn |            39.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              34 |
# |          EpLenMean |             108 |
# |           EpLenStd |            39.4 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        1.41e+05 |
# ----------------------------------------
# ********** Iteration 28 ************
# the loss is 0.00780238
# ----------------------------------------
# |               Time |              79 |
# |          Iteration |              28 |
# |      AverageReturn |             114 |
# |          StdReturn |            49.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              28 |
# |          EpLenMean |             114 |
# |           EpLenStd |            49.2 |
# | TimestepsThisBatch |        5.01e+03 |
# |     TimestepsSoFar |        1.46e+05 |
# ----------------------------------------
# ********** Iteration 29 ************
# the loss is 0.00394359
# ----------------------------------------
# |               Time |            82.6 |
# |          Iteration |              29 |
# |      AverageReturn |             146 |
# |          StdReturn |            41.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              62 |
# |          EpLenMean |             146 |
# |           EpLenStd |            41.8 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        1.51e+05 |
# ----------------------------------------
# ********** Iteration 30 ************
# the loss is -0.00011967
# ----------------------------------------
# |               Time |            86.1 |
# |          Iteration |              30 |
# |      AverageReturn |             164 |
# |          StdReturn |            43.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              44 |
# |          EpLenMean |             164 |
# |           EpLenStd |            43.6 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        1.56e+05 |
# ----------------------------------------
# ********** Iteration 31 ************
# the loss is 0.00946578
# ----------------------------------------
# |               Time |            89.7 |
# |          Iteration |              31 |
# |      AverageReturn |             162 |
# |          StdReturn |            37.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              60 |
# |          EpLenMean |             162 |
# |           EpLenStd |            37.3 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.61e+05 |
# ----------------------------------------
# ********** Iteration 32 ************
# the loss is 0.0107424
# ----------------------------------------
# |               Time |            93.3 |
# |          Iteration |              32 |
# |      AverageReturn |             175 |
# |          StdReturn |            37.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              44 |
# |          EpLenMean |             175 |
# |           EpLenStd |            37.5 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        1.66e+05 |
# ----------------------------------------
# ********** Iteration 33 ************
# the loss is 0.00840536
# ----------------------------------------
# |               Time |            96.9 |
# |          Iteration |              33 |
# |      AverageReturn |             176 |
# |          StdReturn |            31.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             106 |
# |          EpLenMean |             176 |
# |           EpLenStd |            31.7 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        1.71e+05 |
# ----------------------------------------
# ********** Iteration 34 ************
# the loss is 0.00293807
# ----------------------------------------
# |               Time |             100 |
# |          Iteration |              34 |
# |      AverageReturn |             164 |
# |          StdReturn |            39.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              58 |
# |          EpLenMean |             164 |
# |           EpLenStd |            39.9 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        1.77e+05 |
# ----------------------------------------
# ********** Iteration 35 ************
# the loss is 0.00600025
# ----------------------------------------
# |               Time |             104 |
# |          Iteration |              35 |
# |      AverageReturn |             189 |
# |          StdReturn |            22.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             117 |
# |          EpLenMean |             189 |
# |           EpLenStd |            22.4 |
# | TimestepsThisBatch |         5.1e+03 |
# |     TimestepsSoFar |        1.82e+05 |
# ----------------------------------------
# ********** Iteration 36 ************
# the loss is 0.0109551
# ----------------------------------------
# |               Time |             108 |
# |          Iteration |              36 |
# |      AverageReturn |             184 |
# |          StdReturn |            37.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              34 |
# |          EpLenMean |             184 |
# |           EpLenStd |            37.1 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        1.87e+05 |
# ----------------------------------------
# ********** Iteration 37 ************
# the loss is 0.00112452
# ----------------------------------------
# |               Time |             111 |
# |          Iteration |              37 |
# |      AverageReturn |             179 |
# |          StdReturn |            30.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             104 |
# |          EpLenMean |             179 |
# |           EpLenStd |            30.4 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.92e+05 |
# ----------------------------------------
# ********** Iteration 38 ************
# the loss is 0.00554334
# ----------------------------------------
# |               Time |             115 |
# |          Iteration |              38 |
# |      AverageReturn |             179 |
# |          StdReturn |            31.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              96 |
# |          EpLenMean |             179 |
# |           EpLenStd |            31.8 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |        1.97e+05 |
# ----------------------------------------
# ********** Iteration 39 ************
# the loss is 0.00328438
# ----------------------------------------
# |               Time |             120 |
# |          Iteration |              39 |
# |      AverageReturn |             186 |
# |          StdReturn |            32.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              69 |
# |          EpLenMean |             186 |
# |           EpLenStd |            32.6 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.02e+05 |
# ----------------------------------------
# ********** Iteration 40 ************
# the loss is 0.00515577
# ----------------------------------------
# |               Time |             124 |
# |          Iteration |              40 |
# |      AverageReturn |             181 |
# |          StdReturn |            33.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              98 |
# |          EpLenMean |             181 |
# |           EpLenStd |            33.6 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        2.07e+05 |
# ----------------------------------------
# ********** Iteration 41 ************
# the loss is 0.00188449
# ----------------------------------------
# |               Time |             128 |
# |          Iteration |              41 |
# |      AverageReturn |             190 |
# |          StdReturn |            22.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             114 |
# |          EpLenMean |             190 |
# |           EpLenStd |            22.2 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        2.12e+05 |
# ----------------------------------------
# ********** Iteration 42 ************
# the loss is 0.00167386
# ----------------------------------------
# |               Time |             131 |
# |          Iteration |              42 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.74 |
# |          MaxReturn |             200 |
# |          MinReturn |             172 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.74 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        2.17e+05 |
# ----------------------------------------
# ********** Iteration 43 ************
# the loss is 0.00366383
# ----------------------------------------
# |               Time |             135 |
# |          Iteration |              43 |
# |      AverageReturn |             198 |
# |          StdReturn |            7.79 |
# |          MaxReturn |             200 |
# |          MinReturn |             163 |
# |          EpLenMean |             198 |
# |           EpLenStd |            7.79 |
# | TimestepsThisBatch |        5.14e+03 |
# |     TimestepsSoFar |        2.23e+05 |
# ----------------------------------------
# ********** Iteration 44 ************
# the loss is 0.00125449
# ----------------------------------------
# |               Time |             139 |
# |          Iteration |              44 |
# |      AverageReturn |             196 |
# |          StdReturn |            13.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             141 |
# |          EpLenMean |             196 |
# |           EpLenStd |            13.5 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        2.28e+05 |
# ----------------------------------------
# ********** Iteration 45 ************
# the loss is 0.00894949
# ----------------------------------------
# |               Time |             143 |
# |          Iteration |              45 |
# |      AverageReturn |             194 |
# |          StdReturn |            19.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             117 |
# |          EpLenMean |             194 |
# |           EpLenStd |            19.3 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        2.33e+05 |
# ----------------------------------------
# ********** Iteration 46 ************
# the loss is 0.00383252
# ----------------------------------------
# |               Time |             146 |
# |          Iteration |              46 |
# |      AverageReturn |             195 |
# |          StdReturn |            17.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             132 |
# |          EpLenMean |             195 |
# |           EpLenStd |            17.9 |
# | TimestepsThisBatch |        5.07e+03 |
# |     TimestepsSoFar |        2.38e+05 |
# ----------------------------------------
# ********** Iteration 47 ************
# the loss is 0.00255981
# ----------------------------------------
# |               Time |             150 |
# |          Iteration |              47 |
# |      AverageReturn |             199 |
# |          StdReturn |            4.39 |
# |          MaxReturn |             200 |
# |          MinReturn |             178 |
# |          EpLenMean |             199 |
# |           EpLenStd |            4.39 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        2.43e+05 |
# ----------------------------------------
# ********** Iteration 48 ************
# the loss is -0.00236625
# ----------------------------------------
# |               Time |             154 |
# |          Iteration |              48 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.48e+05 |
# ----------------------------------------
# ********** Iteration 49 ************
# the loss is 0.00348155
# ----------------------------------------
# |               Time |             158 |
# |          Iteration |              49 |
# |      AverageReturn |             197 |
# |          StdReturn |            16.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             197 |
# |           EpLenStd |            16.9 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        2.53e+05 |
# ----------------------------------------
# ********** Iteration 50 ************
# the loss is -0.00250523
# ----------------------------------------
# |               Time |             162 |
# |          Iteration |              50 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.58e+05 |
# ----------------------------------------
# ********** Iteration 51 ************
# the loss is -0.000505685
# ----------------------------------------
# |               Time |             165 |
# |          Iteration |              51 |
# |      AverageReturn |             199 |
# |          StdReturn |            6.73 |
# |          MaxReturn |             200 |
# |          MinReturn |             165 |
# |          EpLenMean |             199 |
# |           EpLenStd |            6.73 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        2.64e+05 |
# ----------------------------------------
# ********** Iteration 52 ************
# the loss is 0.0124934
# ----------------------------------------
# |               Time |             169 |
# |          Iteration |              52 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.38 |
# |          MaxReturn |             200 |
# |          MinReturn |             172 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.38 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        2.69e+05 |
# ----------------------------------------
# ********** Iteration 53 ************
# the loss is 0.00641193
# ----------------------------------------
# |               Time |             173 |
# |          Iteration |              53 |
# |      AverageReturn |             200 |
# |          StdReturn |            2.31 |
# |          MaxReturn |             200 |
# |          MinReturn |             188 |
# |          EpLenMean |             200 |
# |           EpLenStd |            2.31 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        2.74e+05 |
# ----------------------------------------
# ********** Iteration 54 ************
# the loss is 0.00227901
# ----------------------------------------
# |               Time |             177 |
# |          Iteration |              54 |
# |      AverageReturn |             198 |
# |          StdReturn |            7.69 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             198 |
# |           EpLenStd |            7.69 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        2.79e+05 |
# ----------------------------------------
# ********** Iteration 55 ************
# the loss is -0.000225445
# ----------------------------------------
# |               Time |             180 |
# |          Iteration |              55 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.84e+05 |
# ----------------------------------------
# ********** Iteration 56 ************
# the loss is -0.00143165
# ----------------------------------------
# |               Time |             185 |
# |          Iteration |              56 |
# |      AverageReturn |             199 |
# |          StdReturn |            3.85 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             199 |
# |           EpLenStd |            3.85 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        2.89e+05 |
# ----------------------------------------
# ********** Iteration 57 ************
# the loss is 0.00105602
# ----------------------------------------
# |               Time |             189 |
# |          Iteration |              57 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        2.95e+05 |
# ----------------------------------------
# ********** Iteration 58 ************
# the loss is 0.000388884
# ----------------------------------------
# |               Time |             194 |
# |          Iteration |              58 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |           3e+05 |
# ----------------------------------------
# ********** Iteration 59 ************
# the loss is 0.00385012
# ----------------------------------------
# |               Time |             198 |
# |          Iteration |              59 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.05e+05 |
# ----------------------------------------
# ********** Iteration 60 ************
# the loss is 0.00458781
# ----------------------------------------
# |               Time |             202 |
# |          Iteration |              60 |
# |      AverageReturn |             196 |
# |          StdReturn |            18.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             106 |
# |          EpLenMean |             196 |
# |           EpLenStd |            18.1 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |         3.1e+05 |
# ----------------------------------------
# ********** Iteration 61 ************
# the loss is -0.00660981
# ----------------------------------------
# |               Time |             205 |
# |          Iteration |              61 |
# |      AverageReturn |             196 |
# |          StdReturn |            20.8 |
# |          MaxReturn |             200 |
# |          MinReturn |              92 |
# |          EpLenMean |             196 |
# |           EpLenStd |            20.8 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        3.15e+05 |
# ----------------------------------------
# ********** Iteration 62 ************
# the loss is -0.00211812
# ----------------------------------------
# |               Time |             209 |
# |          Iteration |              62 |
# |      AverageReturn |             193 |
# |          StdReturn |            23.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              82 |
# |          EpLenMean |             193 |
# |           EpLenStd |            23.4 |
# | TimestepsThisBatch |        5.02e+03 |
# |     TimestepsSoFar |         3.2e+05 |
# ----------------------------------------
# ********** Iteration 63 ************
# the loss is 0.00252249
# ----------------------------------------
# |               Time |             213 |
# |          Iteration |              63 |
# |      AverageReturn |             196 |
# |          StdReturn |            15.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             120 |
# |          EpLenMean |             196 |
# |           EpLenStd |            15.5 |
# | TimestepsThisBatch |        5.11e+03 |
# |     TimestepsSoFar |        3.25e+05 |
# ----------------------------------------
# ********** Iteration 64 ************
# the loss is 3.62637e-05
# ----------------------------------------
# |               Time |             217 |
# |          Iteration |              64 |
# |      AverageReturn |             195 |
# |          StdReturn |            17.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             110 |
# |          EpLenMean |             195 |
# |           EpLenStd |            17.8 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |         3.3e+05 |
# ----------------------------------------
# ********** Iteration 65 ************
# the loss is -0.00275918
# ----------------------------------------
# |               Time |             221 |
# |          Iteration |              65 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.36e+05 |
# ----------------------------------------
# ********** Iteration 66 ************
# the loss is 0.00352665
# ----------------------------------------
# |               Time |             225 |
# |          Iteration |              66 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.15 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.15 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        3.41e+05 |
# ----------------------------------------
# ********** Iteration 67 ************
# the loss is 0.000783102
# ----------------------------------------
# |               Time |             229 |
# |          Iteration |              67 |
# |      AverageReturn |             199 |
# |          StdReturn |            3.93 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             199 |
# |           EpLenStd |            3.93 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        3.46e+05 |
# ----------------------------------------
# ********** Iteration 68 ************
# the loss is -0.0017479
# ----------------------------------------
# |               Time |             233 |
# |          Iteration |              68 |
# |      AverageReturn |             199 |
# |          StdReturn |            5.58 |
# |          MaxReturn |             200 |
# |          MinReturn |             171 |
# |          EpLenMean |             199 |
# |           EpLenStd |            5.58 |
# | TimestepsThisBatch |        5.17e+03 |
# |     TimestepsSoFar |        3.51e+05 |
# ----------------------------------------
# ********** Iteration 69 ************
# the loss is 0.00673468
# ----------------------------------------
# |               Time |             238 |
# |          Iteration |              69 |
# |      AverageReturn |             196 |
# |          StdReturn |            22.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              84 |
# |          EpLenMean |             196 |
# |           EpLenStd |            22.3 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        3.56e+05 |
# ----------------------------------------
# ********** Iteration 70 ************
# the loss is -0.00210241
# ----------------------------------------
# |               Time |             242 |
# |          Iteration |              70 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.61e+05 |
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is 0.00521626
# ----------------------------------------
# |               Time |             246 |
# |          Iteration |              71 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.67e+05 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is 0.000784664
# ----------------------------------------
# |               Time |             250 |
# |          Iteration |              72 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.72e+05 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is -0.000367199
# ----------------------------------------
# |               Time |             254 |
# |          Iteration |              73 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.77e+05 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is -0.0110326
# ----------------------------------------
# |               Time |             258 |
# |          Iteration |              74 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.82e+05 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -0.0049659
# ----------------------------------------
# |               Time |             262 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.87e+05 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -0.00312461
# ----------------------------------------
# |               Time |             266 |
# |          Iteration |              76 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.93e+05 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -0.00419928
# ----------------------------------------
# |               Time |             270 |
# |          Iteration |              77 |
# |      AverageReturn |             196 |
# |          StdReturn |              21 |
# |          MaxReturn |             200 |
# |          MinReturn |              91 |
# |          EpLenMean |             196 |
# |           EpLenStd |              21 |
# | TimestepsThisBatch |        5.09e+03 |
# |     TimestepsSoFar |        3.98e+05 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is -0.00255102
# ----------------------------------------
# |               Time |             273 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.03e+05 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.00268225
# ----------------------------------------
# |               Time |             277 |
# |          Iteration |              79 |
# |      AverageReturn |             199 |
# |          StdReturn |            3.06 |
# |          MaxReturn |             200 |
# |          MinReturn |             185 |
# |          EpLenMean |             199 |
# |           EpLenStd |            3.06 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        4.08e+05 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -0.00508708
# ----------------------------------------
# |               Time |             281 |
# |          Iteration |              80 |
# |      AverageReturn |             199 |
# |          StdReturn |            3.65 |
# |          MaxReturn |             200 |
# |          MinReturn |             181 |
# |          EpLenMean |             199 |
# |           EpLenStd |            3.65 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        4.13e+05 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.000777006
# ----------------------------------------
# |               Time |             285 |
# |          Iteration |              81 |
# |      AverageReturn |             195 |
# |          StdReturn |            23.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              80 |
# |          EpLenMean |             195 |
# |           EpLenStd |            23.1 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        4.18e+05 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is 0.00527334
# ----------------------------------------
# |               Time |             290 |
# |          Iteration |              82 |
# |      AverageReturn |             191 |
# |          StdReturn |            28.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              83 |
# |          EpLenMean |             191 |
# |           EpLenStd |            28.6 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |        4.24e+05 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -0.0017423
# ----------------------------------------
# |               Time |             294 |
# |          Iteration |              83 |
# |      AverageReturn |             192 |
# |          StdReturn |            27.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              89 |
# |          EpLenMean |             192 |
# |           EpLenStd |            27.7 |
# | TimestepsThisBatch |        5.19e+03 |
# |     TimestepsSoFar |        4.29e+05 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -0.00175861
# ----------------------------------------
# |               Time |             297 |
# |          Iteration |              84 |
# |      AverageReturn |             200 |
# |          StdReturn |            1.15 |
# |          MaxReturn |             200 |
# |          MinReturn |             194 |
# |          EpLenMean |             200 |
# |           EpLenStd |            1.15 |
# ...
# the loss is 0.00608958
# ----------------------------------------
# |               Time |             242 |
# |          Iteration |              71 |
# |      AverageReturn |             197 |
# |          StdReturn |             9.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             153 |
# |          EpLenMean |             197 |
# |           EpLenStd |             9.9 |
# | TimestepsThisBatch |        5.13e+03 |
# |     TimestepsSoFar |        3.66e+05 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is 0.00213312
# ----------------------------------------
# |               Time |             246 |
# |          Iteration |              72 |
# |      AverageReturn |             200 |
# |          StdReturn |           0.385 |
# |          MaxReturn |             200 |
# |          MinReturn |             198 |
# |          EpLenMean |             200 |
# |           EpLenStd |           0.385 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.71e+05 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is -0.00421939
# ----------------------------------------
# |               Time |             250 |
# |          Iteration |              73 |
# |      AverageReturn |             198 |
# |          StdReturn |            7.69 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             198 |
# |           EpLenStd |            7.69 |
# | TimestepsThisBatch |        5.16e+03 |
# |     TimestepsSoFar |        3.76e+05 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is -0.00216991
# ----------------------------------------
# |               Time |             254 |
# |          Iteration |              74 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.82e+05 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is 0.00219833
# ----------------------------------------
# |               Time |             258 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.87e+05 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -0.0013771
# ----------------------------------------
# |               Time |             262 |
# |          Iteration |              76 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.92e+05 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -0.00333492
# ----------------------------------------
# |               Time |             266 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        3.97e+05 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is -0.00232681
# ----------------------------------------
# |               Time |             270 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.02e+05 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.00381875
# ----------------------------------------
# |               Time |             274 |
# |          Iteration |              79 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.08e+05 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is 0.00291323
# ----------------------------------------
# |               Time |             278 |
# |          Iteration |              80 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.13e+05 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.00424796
# ----------------------------------------
# |               Time |             282 |
# |          Iteration |              81 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.18e+05 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -0.000247152
# ----------------------------------------
# |               Time |             286 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.23e+05 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is 0.00497247
# ----------------------------------------
# |               Time |             290 |
# |          Iteration |              83 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.28e+05 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is 0.000508804
# ----------------------------------------
# |               Time |             294 |
# |          Iteration |              84 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.34e+05 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is 0.00496795
# ----------------------------------------
# |               Time |             299 |
# |          Iteration |              85 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.39e+05 |
# ----------------------------------------
# ********** Iteration 86 ************
# the loss is -0.000161078
# ----------------------------------------
# |               Time |             302 |
# |          Iteration |              86 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.44e+05 |
# ----------------------------------------
# ********** Iteration 87 ************
# the loss is 0.00111412
# ----------------------------------------
# |               Time |             306 |
# |          Iteration |              87 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.49e+05 |
# ----------------------------------------
# ********** Iteration 88 ************
# the loss is 0.00118782
# ----------------------------------------
# |               Time |             310 |
# |          Iteration |              88 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.54e+05 |
# ----------------------------------------
# ********** Iteration 89 ************
# the loss is -0.00663148
# ----------------------------------------
# |               Time |             314 |
# |          Iteration |              89 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         4.6e+05 |
# ----------------------------------------
# ********** Iteration 90 ************
# the loss is -0.00584244
# ----------------------------------------
# |               Time |             318 |
# |          Iteration |              90 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |        4.65e+05 |
# ----------------------------------------
# ********** Iteration 91 ************
# the loss is -0.000715516
# ----------------------------------------
# |               Time |             322 |
# |          Iteration |              91 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         5.2e+03 |
# |     TimestepsSoFar |         4.7e+05 |
# ----------------------------------------
# ********** Iteration 92 ************
# the loss is -0.00201609
# ----------------------------------------
# |               Time |             326 |
# |          Iteration |              92 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.72 |
# |          MaxReturn |             200 |
# |          MinReturn |             188 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.72 |
# | TimestepsThisBatch |        5.18e+03 |
# |     TimestepsSoFar |        4.75e+05 |
# ----------------------------------------
# ********** Iteration 93 ************
# the loss is -0.000154353
# ----------------------------------------
# |               Time |             330 |
# |          Iteration |              93 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.94 |
# |          MaxReturn |             200 |
# |          MinReturn |             174 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.94 |
# | TimestepsThisBatch |        5.15e+03 |
# |     TimestepsSoFar |         4.8e+05 |
# ----------------------------------------
# ********** Iteration 94 ************
# the loss is -0.003801
# ----------------------------------------
# |               Time |             335 |
# |          Iteration |              94 |
# |      AverageReturn |             195 |
# |          StdReturn |              15 |
# |          MaxReturn |             200 |
# |          MinReturn |             134 |
# |          EpLenMean |             195 |
# |           EpLenStd |              15 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        4.85e+05 |
# ----------------------------------------
# ********** Iteration 95 ************
# the loss is -0.000652214
# ----------------------------------------
# |               Time |             339 |
# |          Iteration |              95 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.5 |
# |          MaxReturn |             200 |
# |          MinReturn |             154 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.5 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |         4.9e+05 |
# ----------------------------------------
# ********** Iteration 96 ************
# the loss is 0.00457908
# ----------------------------------------
# |               Time |             343 |
# |          Iteration |              96 |
# |      AverageReturn |             195 |
# |          StdReturn |            9.84 |
# |          MaxReturn |             200 |
# |          MinReturn |             166 |
# |          EpLenMean |             195 |
# |           EpLenStd |            9.84 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        4.95e+05 |
# ----------------------------------------
# ********** Iteration 97 ************
# the loss is 0.00122109
# ----------------------------------------
# |               Time |             347 |
# |          Iteration |              97 |
# |      AverageReturn |             195 |
# |          StdReturn |            9.98 |
# |          MaxReturn |             200 |
# |          MinReturn |             166 |
# |          EpLenMean |             195 |
# |           EpLenStd |            9.98 |
# | TimestepsThisBatch |        5.08e+03 |
# |     TimestepsSoFar |        5.01e+05 |
# ----------------------------------------
# ********** Iteration 98 ************
# the loss is 0.00209326
# ----------------------------------------
# |               Time |             351 |
# |          Iteration |              98 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             151 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.4 |
# | TimestepsThisBatch |        5.06e+03 |
# |     TimestepsSoFar |        5.06e+05 |
# ----------------------------------------
# ********** Iteration 99 ************
# the loss is 0.00305678
# ----------------------------------------
# |               Time |             355 |
# |          Iteration |              99 |
# |      AverageReturn |             194 |
# |          StdReturn |            10.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             194 |
# |           EpLenStd |            10.7 |
# | TimestepsThisBatch |        5.04e+03 |
# |     TimestepsSoFar |        5.11e+05 |
# ----------------------------------------

# %%
# !python ../train_pg_f18.py CartPole-v0 -n 100 -b 1000 -e 3 -rtg --exp_name sb_rtg_na
# Out:
# Running experiment with seed 1
# Logging data to data/sb_rtg_na_CartPole-v0_11-09-2019_17-29-23/1/log.txt
# ../train_pg_f18.py:65: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   args = inspect.getargspec(train_PG)[0]
# /Users/matthewhunt/anaconda/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ********** Iteration 0 ************
# the loss is 0.00848375
# ----------------------------------------
# |               Time |            2.59 |
# |          Iteration |               0 |
# |      AverageReturn |            24.3 |
# |          StdReturn |            11.1 |
# |          MaxReturn |              56 |
# |          MinReturn |               8 |
# |          EpLenMean |            24.3 |
# |           EpLenStd |            11.1 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        1.02e+03 |
# ----------------------------------------
# ********** Iteration 1 ************
# the loss is 0.00979037
# ----------------------------------------
# |               Time |            3.13 |
# |          Iteration |               1 |
# |      AverageReturn |            23.7 |
# |          StdReturn |            10.8 |
# |          MaxReturn |              54 |
# |          MinReturn |              10 |
# |          EpLenMean |            23.7 |
# |           EpLenStd |            10.8 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        2.04e+03 |
# ----------------------------------------
# ********** Iteration 2 ************
# the loss is 0.00748078
# ----------------------------------------
# |               Time |            3.54 |
# |          Iteration |               2 |
# |      AverageReturn |            31.9 |
# |          StdReturn |            17.9 |
# |          MaxReturn |              92 |
# |          MinReturn |              12 |
# |          EpLenMean |            31.9 |
# |           EpLenStd |            17.9 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        3.06e+03 |
# ----------------------------------------
# ********** Iteration 3 ************
# the loss is 0.0139534
# ----------------------------------------
# |               Time |            4.01 |
# |          Iteration |               3 |
# |      AverageReturn |            35.1 |
# |          StdReturn |            19.5 |
# |          MaxReturn |              77 |
# |          MinReturn |              12 |
# |          EpLenMean |            35.1 |
# |           EpLenStd |            19.5 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        4.08e+03 |
# ----------------------------------------
# ********** Iteration 4 ************
# the loss is 0.0198138
# ----------------------------------------
# |               Time |            4.52 |
# |          Iteration |               4 |
# |      AverageReturn |            37.1 |
# |          StdReturn |            17.5 |
# |          MaxReturn |              81 |
# |          MinReturn |              19 |
# |          EpLenMean |            37.1 |
# |           EpLenStd |            17.5 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        5.08e+03 |
# ----------------------------------------
# ********** Iteration 5 ************
# the loss is 0.0100713
# ----------------------------------------
# |               Time |            5.02 |
# |          Iteration |               5 |
# |      AverageReturn |              39 |
# |          StdReturn |            15.3 |
# |          MaxReturn |              70 |
# |          MinReturn |              14 |
# |          EpLenMean |              39 |
# |           EpLenStd |            15.3 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |         6.1e+03 |
# ----------------------------------------
# ********** Iteration 6 ************
# the loss is 0.00360922
# ----------------------------------------
# |               Time |            5.56 |
# |          Iteration |               6 |
# |      AverageReturn |            49.8 |
# |          StdReturn |            28.1 |
# |          MaxReturn |             136 |
# |          MinReturn |              19 |
# |          EpLenMean |            49.8 |
# |           EpLenStd |            28.1 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        7.19e+03 |
# ----------------------------------------
# ********** Iteration 7 ************
# the loss is 0.00947313
# ----------------------------------------
# |               Time |            6.04 |
# |          Iteration |               7 |
# |      AverageReturn |            41.9 |
# |          StdReturn |            20.5 |
# |          MaxReturn |              95 |
# |          MinReturn |              17 |
# |          EpLenMean |            41.9 |
# |           EpLenStd |            20.5 |
# | TimestepsThisBatch |        1.00e+03 |
# |     TimestepsSoFar |         8.2e+03 |
# ----------------------------------------
# ********** Iteration 8 ************
# the loss is 0.0116609
# ----------------------------------------
# |               Time |            6.57 |
# |          Iteration |               8 |
# |      AverageReturn |            50.9 |
# |          StdReturn |            30.5 |
# |          MaxReturn |             127 |
# |          MinReturn |              14 |
# |          EpLenMean |            50.9 |
# |           EpLenStd |            30.5 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        9.21e+03 |
# ----------------------------------------
# ********** Iteration 9 ************
# the loss is 0.00694453
# ----------------------------------------
# |               Time |            7.08 |
# |          Iteration |               9 |
# |      AverageReturn |            47.9 |
# |          StdReturn |            18.1 |
# |          MaxReturn |              88 |
# |          MinReturn |              19 |
# |          EpLenMean |            47.9 |
# |           EpLenStd |            18.1 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.02e+04 |
# ----------------------------------------
# ********** Iteration 10 ************
# the loss is -0.000326563
# ----------------------------------------
# |               Time |            7.56 |
# |          Iteration |              10 |
# |      AverageReturn |            50.4 |
# |          StdReturn |            24.2 |
# |          MaxReturn |             102 |
# |          MinReturn |              24 |
# |          EpLenMean |            50.4 |
# |           EpLenStd |            24.2 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.12e+04 |
# ----------------------------------------
# ********** Iteration 11 ************
# the loss is 0.00365312
# ----------------------------------------
# |               Time |            8.11 |
# |          Iteration |              11 |
# |      AverageReturn |            65.2 |
# |          StdReturn |            34.1 |
# |          MaxReturn |             146 |
# |          MinReturn |              19 |
# |          EpLenMean |            65.2 |
# |           EpLenStd |            34.1 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        1.23e+04 |
# ----------------------------------------
# ********** Iteration 12 ************
# the loss is -0.00659926
# ----------------------------------------
# |               Time |            8.64 |
# |          Iteration |              12 |
# |      AverageReturn |            59.3 |
# |          StdReturn |            31.2 |
# |          MaxReturn |             128 |
# |          MinReturn |              15 |
# |          EpLenMean |            59.3 |
# |           EpLenStd |            31.2 |
# | TimestepsThisBatch |        1.07e+03 |
# |     TimestepsSoFar |        1.33e+04 |
# ----------------------------------------
# ********** Iteration 13 ************
# the loss is 0.0118187
# ----------------------------------------
# |               Time |            9.06 |
# |          Iteration |              13 |
# |      AverageReturn |            45.6 |
# |          StdReturn |            16.9 |
# |          MaxReturn |              85 |
# |          MinReturn |              16 |
# |          EpLenMean |            45.6 |
# |           EpLenStd |            16.9 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        1.43e+04 |
# ----------------------------------------
# ********** Iteration 14 ************
# the loss is 0.013306
# ----------------------------------------
# |               Time |            9.52 |
# |          Iteration |              14 |
# |      AverageReturn |            55.9 |
# |          StdReturn |            20.7 |
# |          MaxReturn |             109 |
# |          MinReturn |              31 |
# |          EpLenMean |            55.9 |
# |           EpLenStd |            20.7 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        1.53e+04 |
# ----------------------------------------
# ********** Iteration 15 ************
# the loss is 0.0105107
# ----------------------------------------
# |               Time |              10 |
# |          Iteration |              15 |
# |      AverageReturn |            63.3 |
# |          StdReturn |            22.9 |
# |          MaxReturn |             105 |
# |          MinReturn |              30 |
# |          EpLenMean |            63.3 |
# |           EpLenStd |            22.9 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        1.64e+04 |
# ----------------------------------------
# ********** Iteration 16 ************
# the loss is 0.00331512
# ----------------------------------------
# |               Time |            10.5 |
# |          Iteration |              16 |
# |      AverageReturn |            58.7 |
# |          StdReturn |              19 |
# |          MaxReturn |              96 |
# |          MinReturn |              27 |
# |          EpLenMean |            58.7 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        1.75e+04 |
# ----------------------------------------
# ********** Iteration 17 ************
# the loss is 0.0122896
# ----------------------------------------
# |               Time |              11 |
# |          Iteration |              17 |
# |      AverageReturn |            51.7 |
# |          StdReturn |            15.8 |
# |          MaxReturn |              82 |
# |          MinReturn |              18 |
# |          EpLenMean |            51.6 |
# |           EpLenStd |            15.8 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        1.85e+04 |
# ----------------------------------------
# ********** Iteration 18 ************
# the loss is 0.00826297
# ----------------------------------------
# |               Time |            11.5 |
# |          Iteration |              18 |
# |      AverageReturn |            58.4 |
# |          StdReturn |            21.7 |
# |          MaxReturn |             105 |
# |          MinReturn |              30 |
# |          EpLenMean |            58.4 |
# |           EpLenStd |            21.7 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        1.96e+04 |
# ----------------------------------------
# ********** Iteration 19 ************
# the loss is -0.00121431
# ----------------------------------------
# |               Time |            12.1 |
# |          Iteration |              19 |
# |      AverageReturn |            81.5 |
# |          StdReturn |            33.7 |
# |          MaxReturn |             144 |
# |          MinReturn |              40 |
# |          EpLenMean |            81.5 |
# |           EpLenStd |            33.7 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        2.06e+04 |
# ----------------------------------------
# ********** Iteration 20 ************
# the loss is 0.0046872
# ----------------------------------------
# |               Time |            12.6 |
# |          Iteration |              20 |
# |      AverageReturn |            74.9 |
# |          StdReturn |            31.3 |
# |          MaxReturn |             138 |
# |          MinReturn |              22 |
# |          EpLenMean |            74.9 |
# |           EpLenStd |            31.3 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        2.17e+04 |
# ----------------------------------------
# ********** Iteration 21 ************
# the loss is 0.0134383
# ----------------------------------------
# |               Time |            13.1 |
# |          Iteration |              21 |
# |      AverageReturn |            63.7 |
# |          StdReturn |              19 |
# |          MaxReturn |             103 |
# |          MinReturn |              35 |
# |          EpLenMean |            63.7 |
# |           EpLenStd |              19 |
# | TimestepsThisBatch |        1.02e+03 |
# |     TimestepsSoFar |        2.28e+04 |
# ----------------------------------------
# ********** Iteration 22 ************
# the loss is -0.00847056
# ----------------------------------------
# |               Time |            13.6 |
# |          Iteration |              22 |
# |      AverageReturn |            72.5 |
# |          StdReturn |              23 |
# |          MaxReturn |             113 |
# |          MinReturn |              40 |
# |          EpLenMean |            72.5 |
# |           EpLenStd |              23 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        2.39e+04 |
# ----------------------------------------
# ********** Iteration 23 ************
# the loss is -0.00229885
# ----------------------------------------
# |               Time |            14.2 |
# |          Iteration |              23 |
# |      AverageReturn |            77.2 |
# |          StdReturn |            30.2 |
# |          MaxReturn |             150 |
# |          MinReturn |              37 |
# |          EpLenMean |            77.2 |
# |           EpLenStd |            30.2 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        2.49e+04 |
# ----------------------------------------
# ********** Iteration 24 ************
# the loss is 0.0150217
# ----------------------------------------
# |               Time |            14.7 |
# |          Iteration |              24 |
# |      AverageReturn |            83.7 |
# |          StdReturn |            19.7 |
# |          MaxReturn |             120 |
# |          MinReturn |              52 |
# |          EpLenMean |            83.7 |
# |           EpLenStd |            19.7 |
# | TimestepsThisBatch |           1e+03 |
# |     TimestepsSoFar |        2.59e+04 |
# ----------------------------------------
# ********** Iteration 25 ************
# the loss is -0.000239619
# ----------------------------------------
# |               Time |            15.3 |
# |          Iteration |              25 |
# |      AverageReturn |            95.8 |
# |          StdReturn |            38.5 |
# |          MaxReturn |             200 |
# |          MinReturn |              34 |
# |          EpLenMean |            95.8 |
# |           EpLenStd |            38.5 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        2.69e+04 |
# ----------------------------------------
# ********** Iteration 26 ************
# the loss is 0.00322999
# ----------------------------------------
# |               Time |            15.8 |
# |          Iteration |              26 |
# |      AverageReturn |            85.6 |
# |          StdReturn |            31.6 |
# |          MaxReturn |             152 |
# |          MinReturn |              54 |
# |          EpLenMean |            85.6 |
# |           EpLenStd |            31.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        2.79e+04 |
# ----------------------------------------
# ********** Iteration 27 ************
# the loss is 0.0101226
# ----------------------------------------
# |               Time |            16.4 |
# |          Iteration |              27 |
# |      AverageReturn |             144 |
# |          StdReturn |            41.6 |
# |          MaxReturn |             200 |
# |          MinReturn |              63 |
# |          EpLenMean |             144 |
# |           EpLenStd |            41.6 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |         2.9e+04 |
# ----------------------------------------
# ********** Iteration 28 ************
# the loss is -0.00408851
# ----------------------------------------
# |               Time |            17.2 |
# |          Iteration |              28 |
# |      AverageReturn |             128 |
# |          StdReturn |            59.4 |
# |          MaxReturn |             200 |
# |          MinReturn |              37 |
# |          EpLenMean |             128 |
# |           EpLenStd |            59.4 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |           3e+04 |
# ----------------------------------------
# ********** Iteration 29 ************
# the loss is 0.00500667
# ----------------------------------------
# |               Time |            17.9 |
# |          Iteration |              29 |
# |      AverageReturn |             172 |
# |          StdReturn |            29.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             122 |
# |          EpLenMean |             172 |
# |           EpLenStd |            29.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |         3.1e+04 |
# ----------------------------------------
# ********** Iteration 30 ************
# the loss is -0.00249752
# ----------------------------------------
# |               Time |            18.6 |
# |          Iteration |              30 |
# |      AverageReturn |             120 |
# |          StdReturn |              49 |
# |          MaxReturn |             200 |
# |          MinReturn |              45 |
# |          EpLenMean |             120 |
# |           EpLenStd |              49 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        3.21e+04 |
# ----------------------------------------
# ********** Iteration 31 ************
# the loss is 0.0256459
# ----------------------------------------
# |               Time |            19.2 |
# |          Iteration |              31 |
# |      AverageReturn |             122 |
# |          StdReturn |            33.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              79 |
# |          EpLenMean |             122 |
# |           EpLenStd |            33.7 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        3.32e+04 |
# ----------------------------------------
# ********** Iteration 32 ************
# the loss is 0.0128052
# ----------------------------------------
# |               Time |              20 |
# |          Iteration |              32 |
# |      AverageReturn |             120 |
# |          StdReturn |            53.7 |
# |          MaxReturn |             200 |
# |          MinReturn |              31 |
# |          EpLenMean |             120 |
# |           EpLenStd |            53.7 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        3.43e+04 |
# ----------------------------------------
# ********** Iteration 33 ************
# the loss is 0.0216928
# ----------------------------------------
# |               Time |            20.7 |
# |          Iteration |              33 |
# |      AverageReturn |             151 |
# |          StdReturn |            38.2 |
# |          MaxReturn |             200 |
# |          MinReturn |              70 |
# |          EpLenMean |             151 |
# |           EpLenStd |            38.2 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        3.53e+04 |
# ----------------------------------------
# ********** Iteration 34 ************
# the loss is -0.000450816
# ----------------------------------------
# |               Time |            21.4 |
# |          Iteration |              34 |
# |      AverageReturn |             168 |
# |          StdReturn |            32.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             121 |
# |          EpLenMean |             168 |
# |           EpLenStd |            32.2 |
# | TimestepsThisBatch |        1.01e+03 |
# |     TimestepsSoFar |        3.63e+04 |
# ----------------------------------------
# ********** Iteration 35 ************
# the loss is 0.00157982
# ----------------------------------------
# |               Time |            22.1 |
# |          Iteration |              35 |
# |      AverageReturn |             151 |
# |          StdReturn |            34.1 |
# |          MaxReturn |             200 |
# |          MinReturn |              97 |
# |          EpLenMean |             151 |
# |           EpLenStd |            34.1 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        3.74e+04 |
# ----------------------------------------
# ********** Iteration 36 ************
# the loss is -0.0061436
# ----------------------------------------
# |               Time |            22.8 |
# |          Iteration |              36 |
# |      AverageReturn |             172 |
# |          StdReturn |            22.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             145 |
# |          EpLenMean |             172 |
# |           EpLenStd |            22.6 |
# | TimestepsThisBatch |        1.03e+03 |
# |     TimestepsSoFar |        3.84e+04 |
# ----------------------------------------
# ********** Iteration 37 ************
# the loss is 0.00659663
# ----------------------------------------
# |               Time |            23.5 |
# |          Iteration |              37 |
# |      AverageReturn |             148 |
# |          StdReturn |            61.9 |
# |          MaxReturn |             200 |
# |          MinReturn |              29 |
# |          EpLenMean |             148 |
# |           EpLenStd |            61.9 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        3.95e+04 |
# ----------------------------------------
# ********** Iteration 38 ************
# the loss is 0.00513944
# ----------------------------------------
# |               Time |            24.3 |
# |          Iteration |              38 |
# |      AverageReturn |             148 |
# |          StdReturn |            46.3 |
# |          MaxReturn |             200 |
# |          MinReturn |              84 |
# |          EpLenMean |             148 |
# |           EpLenStd |            46.3 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        4.05e+04 |
# ----------------------------------------
# ********** Iteration 39 ************
# the loss is 0.00465926
# ----------------------------------------
# |               Time |            25.1 |
# |          Iteration |              39 |
# |      AverageReturn |             174 |
# |          StdReturn |              33 |
# |          MaxReturn |             200 |
# |          MinReturn |             120 |
# |          EpLenMean |             174 |
# |           EpLenStd |              33 |
# | TimestepsThisBatch |        1.04e+03 |
# |     TimestepsSoFar |        4.15e+04 |
# ----------------------------------------
# ********** Iteration 40 ************
# the loss is 0.0256171
# ----------------------------------------
# |               Time |            25.9 |
# |          Iteration |              40 |
# |      AverageReturn |             179 |
# |          StdReturn |              47 |
# |          MaxReturn |             200 |
# |          MinReturn |              74 |
# |          EpLenMean |             179 |
# |           EpLenStd |              47 |
# | TimestepsThisBatch |        1.07e+03 |
# |     TimestepsSoFar |        4.26e+04 |
# ----------------------------------------
# ********** Iteration 41 ************
# the loss is 0.00448889
# ----------------------------------------
# |               Time |            26.7 |
# |          Iteration |              41 |
# |      AverageReturn |             185 |
# |          StdReturn |            27.4 |
# |          MaxReturn |             200 |
# |          MinReturn |             125 |
# |          EpLenMean |             185 |
# |           EpLenStd |            27.4 |
# | TimestepsThisBatch |        1.11e+03 |
# |     TimestepsSoFar |        4.37e+04 |
# ----------------------------------------
# ********** Iteration 42 ************
# the loss is -0.00111985
# ----------------------------------------
# |               Time |            27.5 |
# |          Iteration |              42 |
# |      AverageReturn |             190 |
# |          StdReturn |            23.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             138 |
# |          EpLenMean |             190 |
# |           EpLenStd |            23.1 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        4.49e+04 |
# ----------------------------------------
# ********** Iteration 43 ************
# the loss is 0.0144184
# ----------------------------------------
# |               Time |            28.3 |
# |          Iteration |              43 |
# |      AverageReturn |             175 |
# |          StdReturn |            34.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             102 |
# |          EpLenMean |             175 |
# |           EpLenStd |            34.7 |
# | TimestepsThisBatch |        1.05e+03 |
# |     TimestepsSoFar |        4.59e+04 |
# ----------------------------------------
# ********** Iteration 44 ************
# the loss is -0.00703714
# ----------------------------------------
# |               Time |            29.1 |
# |          Iteration |              44 |
# |      AverageReturn |             161 |
# |          StdReturn |            39.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             110 |
# |          EpLenMean |             161 |
# |           EpLenStd |            39.3 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |         4.7e+04 |
# ----------------------------------------
# ********** Iteration 45 ************
# the loss is -0.000154325
# ----------------------------------------
# |               Time |            29.9 |
# |          Iteration |              45 |
# |      AverageReturn |             184 |
# |          StdReturn |            22.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             146 |
# |          EpLenMean |             184 |
# |           EpLenStd |            22.9 |
# | TimestepsThisBatch |         1.1e+03 |
# |     TimestepsSoFar |        4.81e+04 |
# ----------------------------------------
# ********** Iteration 46 ************
# the loss is 0.00522959
# ----------------------------------------
# |               Time |            30.7 |
# |          Iteration |              46 |
# |      AverageReturn |             182 |
# |          StdReturn |            32.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             182 |
# |           EpLenStd |            32.1 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        4.92e+04 |
# ----------------------------------------
# ********** Iteration 47 ************
# the loss is 0.00239709
# ----------------------------------------
# |               Time |            31.7 |
# |          Iteration |              47 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.04e+04 |
# ----------------------------------------
# ********** Iteration 48 ************
# the loss is 0.0187322
# ----------------------------------------
# |               Time |            32.4 |
# |          Iteration |              48 |
# |      AverageReturn |             182 |
# |          StdReturn |            26.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             134 |
# |          EpLenMean |             182 |
# |           EpLenStd |            26.2 |
# | TimestepsThisBatch |        1.09e+03 |
# |     TimestepsSoFar |        5.15e+04 |
# ----------------------------------------
# ********** Iteration 49 ************
# the loss is 0.00428317
# ----------------------------------------
# |               Time |            33.5 |
# |          Iteration |              49 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.27e+04 |
# ----------------------------------------
# ********** Iteration 50 ************
# the loss is 0.0120927
# ----------------------------------------
# |               Time |            34.3 |
# |          Iteration |              50 |
# |      AverageReturn |             177 |
# |          StdReturn |            32.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             127 |
# |          EpLenMean |             177 |
# |           EpLenStd |            32.6 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        5.38e+04 |
# ----------------------------------------
# ********** Iteration 51 ************
# the loss is -0.00612478
# ----------------------------------------
# |               Time |            35.4 |
# |          Iteration |              51 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.21 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.21 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |         5.5e+04 |
# ----------------------------------------
# ********** Iteration 52 ************
# the loss is 0.0107623
# ----------------------------------------
# |               Time |            36.4 |
# |          Iteration |              52 |
# |      AverageReturn |             198 |
# |          StdReturn |             4.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             189 |
# |          EpLenMean |             198 |
# |           EpLenStd |             4.1 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        5.62e+04 |
# ----------------------------------------
# ********** Iteration 53 ************
# the loss is 0.00641529
# ----------------------------------------
# |               Time |            37.4 |
# |          Iteration |              53 |
# |      AverageReturn |             189 |
# |          StdReturn |              23 |
# |          MaxReturn |             200 |
# |          MinReturn |             138 |
# |          EpLenMean |             189 |
# |           EpLenStd |              23 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        5.73e+04 |
# ----------------------------------------
# ********** Iteration 54 ************
# the loss is -0.01225
# ----------------------------------------
# |               Time |            38.4 |
# |          Iteration |              54 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        5.85e+04 |
# ----------------------------------------
# ********** Iteration 55 ************
# the loss is 0.00908792
# ----------------------------------------
# |               Time |            39.2 |
# |          Iteration |              55 |
# |      AverageReturn |             185 |
# |          StdReturn |            32.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             112 |
# |          EpLenMean |             185 |
# |           EpLenStd |            32.8 |
# | TimestepsThisBatch |        1.11e+03 |
# |     TimestepsSoFar |        5.96e+04 |
# ----------------------------------------
# ********** Iteration 56 ************
# the loss is 0.00457649
# ----------------------------------------
# |               Time |              40 |
# |          Iteration |              56 |
# |      AverageReturn |             192 |
# |          StdReturn |            16.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             155 |
# |          EpLenMean |             192 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        1.16e+03 |
# |     TimestepsSoFar |        6.08e+04 |
# ----------------------------------------
# ********** Iteration 57 ************
# the loss is -0.00654377
# ----------------------------------------
# |               Time |            40.9 |
# |          Iteration |              57 |
# |      AverageReturn |             198 |
# |          StdReturn |            3.35 |
# |          MaxReturn |             200 |
# |          MinReturn |             191 |
# |          EpLenMean |             198 |
# |           EpLenStd |            3.35 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        6.19e+04 |
# ----------------------------------------
# ********** Iteration 58 ************
# the loss is 0.00105382
# ----------------------------------------
# |               Time |            41.7 |
# |          Iteration |              58 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             126 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.6 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        6.31e+04 |
# ----------------------------------------
# ********** Iteration 59 ************
# the loss is 0.00877511
# ----------------------------------------
# |               Time |            42.7 |
# |          Iteration |              59 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        6.43e+04 |
# ----------------------------------------
# ********** Iteration 60 ************
# the loss is 0.00549403
# ----------------------------------------
# |               Time |            43.4 |
# |          Iteration |              60 |
# |      AverageReturn |             176 |
# |          StdReturn |            32.3 |
# |          MaxReturn |             200 |
# |          MinReturn |             111 |
# |          EpLenMean |             176 |
# |           EpLenStd |            32.3 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        6.53e+04 |
# ----------------------------------------
# ********** Iteration 61 ************
# the loss is 0.00765768
# ----------------------------------------
# |               Time |            44.2 |
# |          Iteration |              61 |
# |      AverageReturn |             180 |
# |          StdReturn |            28.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             133 |
# |          EpLenMean |             180 |
# |           EpLenStd |            28.2 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |        6.64e+04 |
# ----------------------------------------
# ********** Iteration 62 ************
# the loss is 0.00484962
# ----------------------------------------
# |               Time |            45.1 |
# |          Iteration |              62 |
# |      AverageReturn |             196 |
# |          StdReturn |            9.69 |
# |          MaxReturn |             200 |
# |          MinReturn |             174 |
# |          EpLenMean |             196 |
# |           EpLenStd |            9.69 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        6.76e+04 |
# ----------------------------------------
# ********** Iteration 63 ************
# the loss is -0.00674391
# ----------------------------------------
# |               Time |              46 |
# |          Iteration |              63 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        6.88e+04 |
# ----------------------------------------
# ********** Iteration 64 ************
# the loss is 0.00520385
# ----------------------------------------
# |               Time |            46.8 |
# |          Iteration |              64 |
# |      AverageReturn |             186 |
# |          StdReturn |            30.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             118 |
# |          EpLenMean |             186 |
# |           EpLenStd |            30.6 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        6.99e+04 |
# ----------------------------------------
# ********** Iteration 65 ************
# the loss is 0.00660023
# ----------------------------------------
# |               Time |            47.6 |
# |          Iteration |              65 |
# |      AverageReturn |             179 |
# |          StdReturn |            29.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             123 |
# |          EpLenMean |             179 |
# |           EpLenStd |            29.8 |
# | TimestepsThisBatch |        1.08e+03 |
# |     TimestepsSoFar |         7.1e+04 |
# ----------------------------------------
# ********** Iteration 66 ************
# the loss is 0.0186199
# ----------------------------------------
# |               Time |            48.5 |
# |          Iteration |              66 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             168 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.9 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        7.22e+04 |
# ----------------------------------------
# ********** Iteration 67 ************
# the loss is 0.00148079
# ----------------------------------------
# |               Time |            49.4 |
# |          Iteration |              67 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.34e+04 |
# ----------------------------------------
# ********** Iteration 68 ************
# the loss is 0.00897799
# ----------------------------------------
# |               Time |            50.3 |
# |          Iteration |              68 |
# |      AverageReturn |             190 |
# |          StdReturn |            15.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             161 |
# |          EpLenMean |             190 |
# |           EpLenStd |            15.2 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        7.45e+04 |
# ----------------------------------------
# ********** Iteration 69 ************
# the loss is 0.00236846
# ----------------------------------------
# |               Time |            51.2 |
# |          Iteration |              69 |
# |      AverageReturn |             195 |
# |          StdReturn |            11.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             168 |
# |          EpLenMean |             195 |
# |           EpLenStd |            11.9 |
# | TimestepsThisBatch |        1.17e+03 |
# |     TimestepsSoFar |        7.57e+04 |
# ----------------------------------------
# ********** Iteration 70 ************
# the loss is 0.010191
# ----------------------------------------
# |               Time |            52.1 |
# |          Iteration |              70 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.69e+04 |
# ----------------------------------------
# ********** Iteration 71 ************
# the loss is 0.00616164
# ----------------------------------------
# |               Time |              53 |
# |          Iteration |              71 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        7.81e+04 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is -0.00515036
# ----------------------------------------
# |               Time |            53.9 |
# |          Iteration |              72 |
# |      AverageReturn |             194 |
# |          StdReturn |            8.86 |
# |          MaxReturn |             200 |
# |          MinReturn |             180 |
# |          EpLenMean |             194 |
# |           EpLenStd |            8.86 |
# | TimestepsThisBatch |        1.16e+03 |
# |     TimestepsSoFar |        7.92e+04 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is 0.0127718
# ----------------------------------------
# |               Time |            54.8 |
# |          Iteration |              73 |
# |      AverageReturn |             191 |
# |          StdReturn |            16.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             154 |
# |          EpLenMean |             191 |
# |           EpLenStd |            16.8 |
# | TimestepsThisBatch |        1.14e+03 |
# |     TimestepsSoFar |        8.04e+04 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is 0.00593974
# ----------------------------------------
# |               Time |            55.7 |
# |          Iteration |              74 |
# |      AverageReturn |             199 |
# |          StdReturn |            1.86 |
# |          MaxReturn |             200 |
# |          MinReturn |             195 |
# |          EpLenMean |             199 |
# |           EpLenStd |            1.86 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.16e+04 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is 0.0026006
# ----------------------------------------
# |               Time |            56.6 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.28e+04 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is 0.0116807
# ----------------------------------------
# |               Time |            57.4 |
# |          Iteration |              76 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.2 |
# |          MaxReturn |             200 |
# |          MinReturn |             127 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.2 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        8.39e+04 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is -0.00287546
# ----------------------------------------
# |               Time |            58.3 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.51e+04 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is 0.00650467
# ----------------------------------------
# |               Time |            59.3 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.63e+04 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.002553
# ----------------------------------------
# |               Time |            60.2 |
# |          Iteration |              79 |
# |      AverageReturn |             192 |
# |          StdReturn |            12.1 |
# |          MaxReturn |             200 |
# |          MinReturn |             170 |
# |          EpLenMean |             192 |
# |           EpLenStd |            12.1 |
# | TimestepsThisBatch |        1.15e+03 |
# |     TimestepsSoFar |        8.74e+04 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -0.000883234
# ----------------------------------------
# |               Time |            61.1 |
# |          Iteration |              80 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.86e+04 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.000449948
# ----------------------------------------
# |               Time |            61.9 |
# |          Iteration |              81 |
# |      AverageReturn |             187 |
# |          StdReturn |            18.9 |
# |          MaxReturn |             200 |
# |          MinReturn |             160 |
# |          EpLenMean |             187 |
# |           EpLenStd |            18.9 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        8.98e+04 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is -0.001301
# ----------------------------------------
# |               Time |            62.9 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.1e+04 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -0.00304297
# ----------------------------------------
# |               Time |            63.8 |
# |          Iteration |              83 |
# |      AverageReturn |             188 |
# |          StdReturn |            23.8 |
# |          MaxReturn |             200 |
# |          MinReturn |             135 |
# |          EpLenMean |             188 |
# |           EpLenStd |            23.8 |
# | TimestepsThisBatch |        1.12e+03 |
# |     TimestepsSoFar |        9.21e+04 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is -0.00707398
# ----------------------------------------
# |               Time |            64.9 |
# |          Iteration |              84 |
# |      AverageReturn |             199 |
# |          StdReturn |            2.98 |
# |          MaxReturn |             200 |
# |          MinReturn |             192 |
# |          EpLenMean |             199 |
# |           EpLenStd |            2.98 |
# ...
# the loss is 0.014325
# ----------------------------------------
# |               Time |            57.2 |
# |          Iteration |              71 |
# |      AverageReturn |             197 |
# |          StdReturn |            6.34 |
# |          MaxReturn |             200 |
# |          MinReturn |             183 |
# |          EpLenMean |             197 |
# |           EpLenStd |            6.34 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |        7.92e+04 |
# ----------------------------------------
# ********** Iteration 72 ************
# the loss is 0.00811317
# ----------------------------------------
# |               Time |              58 |
# |          Iteration |              72 |
# |      AverageReturn |             188 |
# |          StdReturn |            27.6 |
# |          MaxReturn |             200 |
# |          MinReturn |             126 |
# |          EpLenMean |             188 |
# |           EpLenStd |            27.6 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        8.03e+04 |
# ----------------------------------------
# ********** Iteration 73 ************
# the loss is 0.0140536
# ----------------------------------------
# |               Time |            58.8 |
# |          Iteration |              73 |
# |      AverageReturn |             177 |
# |          StdReturn |              35 |
# |          MaxReturn |             200 |
# |          MinReturn |             109 |
# |          EpLenMean |             177 |
# |           EpLenStd |              35 |
# | TimestepsThisBatch |        1.06e+03 |
# |     TimestepsSoFar |        8.14e+04 |
# ----------------------------------------
# ********** Iteration 74 ************
# the loss is 0.000911962
# ----------------------------------------
# |               Time |            59.7 |
# |          Iteration |              74 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.26e+04 |
# ----------------------------------------
# ********** Iteration 75 ************
# the loss is -0.000248729
# ----------------------------------------
# |               Time |            60.6 |
# |          Iteration |              75 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.38e+04 |
# ----------------------------------------
# ********** Iteration 76 ************
# the loss is -0.00311189
# ----------------------------------------
# |               Time |            61.5 |
# |          Iteration |              76 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         8.5e+04 |
# ----------------------------------------
# ********** Iteration 77 ************
# the loss is 0.00718618
# ----------------------------------------
# |               Time |            62.4 |
# |          Iteration |              77 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.62e+04 |
# ----------------------------------------
# ********** Iteration 78 ************
# the loss is 0.00539348
# ----------------------------------------
# |               Time |            63.3 |
# |          Iteration |              78 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.74e+04 |
# ----------------------------------------
# ********** Iteration 79 ************
# the loss is -0.000138535
# ----------------------------------------
# |               Time |            64.3 |
# |          Iteration |              79 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.86e+04 |
# ----------------------------------------
# ********** Iteration 80 ************
# the loss is -0.00447988
# ----------------------------------------
# |               Time |            65.2 |
# |          Iteration |              80 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        8.98e+04 |
# ----------------------------------------
# ********** Iteration 81 ************
# the loss is -0.00060919
# ----------------------------------------
# |               Time |            66.1 |
# |          Iteration |              81 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.1e+04 |
# ----------------------------------------
# ********** Iteration 82 ************
# the loss is 0.0120963
# ----------------------------------------
# |               Time |            67.1 |
# |          Iteration |              82 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.22e+04 |
# ----------------------------------------
# ********** Iteration 83 ************
# the loss is -0.00393533
# ----------------------------------------
# |               Time |              68 |
# |          Iteration |              83 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.34e+04 |
# ----------------------------------------
# ********** Iteration 84 ************
# the loss is 0.000316729
# ----------------------------------------
# |               Time |            68.9 |
# |          Iteration |              84 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.46e+04 |
# ----------------------------------------
# ********** Iteration 85 ************
# the loss is 0.00391977
# ----------------------------------------
# |               Time |            69.8 |
# |          Iteration |              85 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.58e+04 |
# ----------------------------------------
# ********** Iteration 86 ************
# the loss is 0.00466321
# ----------------------------------------
# |               Time |            70.8 |
# |          Iteration |              86 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         9.7e+04 |
# ----------------------------------------
# ********** Iteration 87 ************
# the loss is 0.00539457
# ----------------------------------------
# |               Time |            71.6 |
# |          Iteration |              87 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.82e+04 |
# ----------------------------------------
# ********** Iteration 88 ************
# the loss is 0.00088137
# ----------------------------------------
# |               Time |            72.6 |
# |          Iteration |              88 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        9.94e+04 |
# ----------------------------------------
# ********** Iteration 89 ************
# the loss is -0.00368755
# ----------------------------------------
# |               Time |            73.5 |
# |          Iteration |              89 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.01e+05 |
# ----------------------------------------
# ********** Iteration 90 ************
# the loss is 0.0129473
# ----------------------------------------
# |               Time |            74.3 |
# |          Iteration |              90 |
# |      AverageReturn |             188 |
# |          StdReturn |            25.7 |
# |          MaxReturn |             200 |
# |          MinReturn |             131 |
# |          EpLenMean |             188 |
# |           EpLenStd |            25.7 |
# | TimestepsThisBatch |        1.13e+03 |
# |     TimestepsSoFar |        1.02e+05 |
# ----------------------------------------
# ********** Iteration 91 ************
# the loss is 0.00333989
# ----------------------------------------
# |               Time |            75.2 |
# |          Iteration |              91 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.03e+05 |
# ----------------------------------------
# ********** Iteration 92 ************
# the loss is -0.00332563
# ----------------------------------------
# |               Time |            76.1 |
# |          Iteration |              92 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.04e+05 |
# ----------------------------------------
# ********** Iteration 93 ************
# the loss is -0.00410316
# ----------------------------------------
# |               Time |            77.3 |
# |          Iteration |              93 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.05e+05 |
# ----------------------------------------
# ********** Iteration 94 ************
# the loss is -0.0260354
# ----------------------------------------
# |               Time |            78.3 |
# |          Iteration |              94 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.07e+05 |
# ----------------------------------------
# ********** Iteration 95 ************
# the loss is -0.00121005
# ----------------------------------------
# |               Time |            79.4 |
# |          Iteration |              95 |
# |      AverageReturn |             196 |
# |          StdReturn |            7.83 |
# |          MaxReturn |             200 |
# |          MinReturn |             179 |
# |          EpLenMean |             196 |
# |           EpLenStd |            7.83 |
# | TimestepsThisBatch |        1.18e+03 |
# |     TimestepsSoFar |        1.08e+05 |
# ----------------------------------------
# ********** Iteration 96 ************
# the loss is -0.00399362
# ----------------------------------------
# |               Time |            80.6 |
# |          Iteration |              96 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.09e+05 |
# ----------------------------------------
# ********** Iteration 97 ************
# the loss is -0.0084759
# ----------------------------------------
# |               Time |            81.6 |
# |          Iteration |              97 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |         1.1e+05 |
# ----------------------------------------
# ********** Iteration 98 ************
# the loss is 0.00840747
# ----------------------------------------
# |               Time |            82.6 |
# |          Iteration |              98 |
# |      AverageReturn |             200 |
# |          StdReturn |               0 |
# |          MaxReturn |             200 |
# |          MinReturn |             200 |
# |          EpLenMean |             200 |
# |           EpLenStd |               0 |
# | TimestepsThisBatch |         1.2e+03 |
# |     TimestepsSoFar |        1.11e+05 |
# ----------------------------------------
# ********** Iteration 99 ************
# the loss is -0.0051726
# ----------------------------------------
# |               Time |            83.5 |
# |          Iteration |              99 |
# |      AverageReturn |             198 |
# |          StdReturn |            5.22 |
# |          MaxReturn |             200 |
# |          MinReturn |             186 |
# |          EpLenMean |             198 |
# |           EpLenStd |            5.22 |
# | TimestepsThisBatch |        1.19e+03 |
# |     TimestepsSoFar |        1.12e+05 |
# ----------------------------------------

# %% [markdown]
# ## Comparison of different training algorithms
#
# Run using:
# python plot.py data/sb_no_rtg_dna_CartPole-v0_10-09-2019_17-26-25 data/sb_rtg_dna_CartPole-v0_10-09-2019_17-27-18 data/sb_rtg_na_CartPole-v0_11-09-2019_17-29-23
#
# and same format for the larger batch size data.
#
# #### Analysis
# So we can see that the network using reward to go seems more solidly convergent on the target of 200 reward.
# Not normalizing the advantage actually helps it to converge faster, which makes sense, because the gradient will be larger, but the variance will also be higher I think, as the rewards that we scale the log probability of an action given a state are larger. This higher variance displays itself, as not Normalizing advantage results in a less thorough or complete convergence to the optimum. This is the case for both large and small batches.
#
#
# The larger batches do not converge much faster if at all, which I believe makes sense, as we use tf.reduce_mean() for the loss function. This means that the gradients should be approximately the same magnitude. However, with larger batches, you expect the estimated gradient to be a better estimate of the true gradient. I Suspect this helps it to convert a little bit faster, and it helps the methods with higher variance converge better to the optimum. Because it seems to decrease the variance for every method, every method performs better at convergence.

# %% [markdown]
# ### Plot of the small_batch trainings: Cart Pole
# ![Plot of the small_batch trainings: Cart Pole](../result_plots/Figure_1.png "Plot of the small_batch trainings: Cart Pole")

# %% [markdown]
# ### Plot of the large_batch trainings: Cart Pole
# ![Plot of the small_batch trainings: Cart Pole](../result_plots/large_batch.png "Plot of the small_batch trainings: Cart Pole")

# %% [markdown]
# ## Cart Pole demonstration!
# The first one is training for 3 iterations of 500 batches per iteration. Not very much training. Not a great result.
#
# The second one is after just 50 iterations of training at 500 batches per iteration. Note this is half the batch size as the above graphs. It's doing well.
#
# Both run like
#
# python train_pg_f18.py CartPole-v0 -n #_iterations -b 500 -e 1 -dna -rtg --exp_name test --save_models --render
#
# So they both used reward to go and didn't normalize advantage

# %% [markdown]
# ## Very Little Training
# ![SegmentLocal](../cart_pole_v0_n3_b500.gif "segment")

# %% [markdown]
# ## Slightly More Training
# ![SegmentLocal](../cart_pole_v0_n50_b500.gif "segment")

# %% [markdown]
# # Continuous Inverted Pendulum
# ## Optimizing batch size
# Ran using the bash script.

# %% [markdown]
# ![Plot of the small_batch trainings: Cart Pole](../result_plots/Another-plot-of-batch-sizes-with-lr-of-5e-3Figure_1.png "Plot of the small_batch trainings: Cart Pole")

# %% [markdown]
# My theory is that when they hit the really high reward they all of a sudden get a large gradient, because the gradient is grad(logprob(action))*reward , and that reward will get really big. This large gradient will then result in a large mistep in a wrong direction, and it then it's catastrophically wrong. Maybe.
#
# Ah, but it should be normalizing the return... I think it is, so it should be that large. The step size should be about the same!
#
# Yet see below. This theory must be wrong. This is using even higher learning rate, and you have better results.
# Maybe it's just drunken enough to quickly stumble into favorable setups.
# IDK though. You still see the catastrophe, but perhaps it just gets back to the good stuff faster:)

# %% [markdown]
# ### Probably wrong Theory about it's bad learning
# Perhaps minimizign -log_prob(action|state) is fine if you're going for maximum likelihood model.
# But maybe minimizing -log_prob(a|s)\*(reward) isn't good, as you're then subsequently trying to make the reward smaller? IDK. Actually that probably doesn't matter too much.
#
# I wonder if the reward going negative is a real problem here. Like with rewards allowed to go negative, you are reversing the sign of log_prob(a|s) and then you should be moving in the opposite direction. Wait, actually we want that for the case of (-) reward [we want to go in the opposite direction in that case]. So that definitely isn't a problem.
#
# Empirically, I should try to maximize the gradient in tensorflow just to make certain.
#
# #### Better thought:
# I think this is catastrophic forgetting that reddit talks about.

# %% [markdown]
# ### Trying a faster learning rate
# ![Plot of the small_batch trainings: Cart Pole](../result_plots/faster_lr.tiff "Plot of the small_batch trainings: Cart Pole")
#
# We see that many of the batch sizes reach the target, and all experience catastrophic forgetting. The smallest batch_size to reach was 2000, but 3k worked a lot faster. We'll go ahead and use 2k to be consistent with the prompt.

# %% [markdown]
# ## Optimizing LR
